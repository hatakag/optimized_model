# %%
# Request more RAM in Colab
a = []
while(1):
  a.append('1')

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
cd /content/drive/My Drive/Graduation research/Graduation research 3/RDGCN-Optimize
# Out:
# /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize

# %%
ls
# Out:
#  data/      output_fr_en.npy  'RDGCN(FR-EN).ipynb'   README.md
#  include/   output_ja_en.npy  'RDGCN(JA-EN).ipynb'   saved_model/
#  main.py    output_zh_en.npy  'RDGCN(ZH-EN).ipynb'

# %%
# shuffle dataset
# !shuf data/ja_en/ref_ent_ids -o data/ja_en/shuffled_ref_ent_ids

# %%
# first 600 epochs
# !python main.py
# Out:
# WARNING:tensorflow:From main.py:18: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loading a file...data/ja_en/ent_ids_1
# loading a file...data/ja_en/ent_ids_2
# loading a file...data/ja_en/shuffled_ref_ent_ids
# loading a file...data/ja_en/ref_r_ids
# loading a file...data/ja_en/triples_1
# loading a file...data/ja_en/triples_2
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:263: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# adding the primal input layer...
# 39594 rows, 300 columns.
# getting a sparse tensor...
# tcmalloc: large alloc 12541485056 bytes == 0x1affc000 @  0x7fb6aaf11001 0x7fb6a838c765 0x7fb6a83f0bb0 0x7fb6a83f2a4f 0x7fb6a8489048 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fb6aab0cb97 0x5b250a
# calculate relation representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Init.py:17: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# first interaction...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:107: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# adding sparse attention layer...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:114: The name tf.sparse_softmax is deprecated. Please use tf.sparse.softmax instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:115: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# second interaction...
# adding sparse attention layer...
# getting loss...
# gcn layers...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:84: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# adding a diag layer...
# adding a diag layer...
# calculate joint entity representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:297: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# getting loss...
# getting loss...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:326: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# initializing...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:330: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:331: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-06-01 08:06:50.010326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-01 08:06:50.012015: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-06-01 08:06:50.012054: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (cc7aae980a4c): /proc/driver/nvidia/version does not exist
# 2020-06-01 08:06:50.018296: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-06-01 08:06:50.020245: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3294bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 08:06:50.020278: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# running...
# Relation:
# For each left:
# Hits@1: 58.60%
# Hits@10: 79.96%
# Hits@50: 88.09%
# Hits@100: 90.55%
# For each right:
# Hits@1: 51.61%
# Hits@10: 76.18%
# Hits@50: 83.18%
# Hits@100: 88.09%
# 1/1000 epochs... 0
# 2/1000 epochs... 0
# 3/1000 epochs... 0
# 4/1000 epochs... 0
# 5/1000 epochs... 0
# 6/1000 epochs... 0
# 7/1000 epochs... 0
# 8/1000 epochs... 0
# 9/1000 epochs... 0
# 10/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 84.69%
# Hits@10: 93.95%
# Hits@50: 97.35%
# Hits@100: 98.11%
# For each right:
# Hits@1: 80.53%
# Hits@10: 90.93%
# Hits@50: 95.65%
# Hits@100: 97.16%
# 11/1000 epochs... 0
# 12/1000 epochs... 0
# 13/1000 epochs... 0
# 14/1000 epochs... 0
# 15/1000 epochs... 0
# 16/1000 epochs... 0
# 17/1000 epochs... 0
# 18/1000 epochs... 0
# 19/1000 epochs... 0
# 20/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 95.65%
# Hits@10: 99.43%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.81%
# Hits@100: 100.00%
# 21/1000 epochs... 0
# 22/1000 epochs... 0
# 23/1000 epochs... 0
# 24/1000 epochs... 0
# 25/1000 epochs... 0
# 26/1000 epochs... 0
# 27/1000 epochs... 0
# 28/1000 epochs... 0
# 29/1000 epochs... 0
# 30/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 98.11%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 98.49%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 31/1000 epochs... 0
# 32/1000 epochs... 0
# 33/1000 epochs... 0
# 34/1000 epochs... 0
# 35/1000 epochs... 0
# 36/1000 epochs... 0
# 37/1000 epochs... 0
# 38/1000 epochs... 0
# 39/1000 epochs... 0
# 40/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 98.49%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 41/1000 epochs... 0
# 42/1000 epochs... 0
# 43/1000 epochs... 0
# 44/1000 epochs... 0
# 45/1000 epochs... 0
# 46/1000 epochs... 0
# 47/1000 epochs... 0
# 48/1000 epochs... 0
# 49/1000 epochs... 0
# 50/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 98.68%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.43%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 51/1000 epochs... 0
# 52/1000 epochs... 0
# 53/1000 epochs... 0
# 54/1000 epochs... 0
# 55/1000 epochs... 0
# 56/1000 epochs... 0
# 57/1000 epochs... 0
# 58/1000 epochs... 0
# 59/1000 epochs... 0
# 60/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.43%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 61/1000 epochs... 0
# 62/1000 epochs... 0
# 63/1000 epochs... 0
# 64/1000 epochs... 0
# 65/1000 epochs... 0
# 66/1000 epochs... 0
# 67/1000 epochs... 0
# 68/1000 epochs... 0
# 69/1000 epochs... 0
# 70/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 71/1000 epochs... 0
# 72/1000 epochs... 0
# 73/1000 epochs... 0
# 74/1000 epochs... 0
# 75/1000 epochs... 0
# 76/1000 epochs... 0
# 77/1000 epochs... 0
# 78/1000 epochs... 0
# 79/1000 epochs... 0
# 80/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 81/1000 epochs... 0
# 82/1000 epochs... 0
# 83/1000 epochs... 0
# 84/1000 epochs... 0
# 85/1000 epochs... 0
# 86/1000 epochs... 0
# 87/1000 epochs... 0
# 88/1000 epochs... 0
# 89/1000 epochs... 0
# 90/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.43%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 91/1000 epochs... 0
# 92/1000 epochs... 0
# 93/1000 epochs... 0
# 94/1000 epochs... 0
# 95/1000 epochs... 0
# 96/1000 epochs... 0
# 97/1000 epochs... 0
# 98/1000 epochs... 0
# 99/1000 epochs... 0
# 100/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 101/1000 epochs... 0
# 102/1000 epochs... 0
# 103/1000 epochs... 0
# 104/1000 epochs... 0
# 105/1000 epochs... 0
# 106/1000 epochs... 0
# 107/1000 epochs... 0
# 108/1000 epochs... 0
# 109/1000 epochs... 0
# 110/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.24%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 111/1000 epochs... 0
# 112/1000 epochs... 0
# 113/1000 epochs... 0
# 114/1000 epochs... 0
# 115/1000 epochs... 0
# 116/1000 epochs... 0
# 117/1000 epochs... 0
# 118/1000 epochs... 0
# 119/1000 epochs... 0
# 120/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.24%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 121/1000 epochs... 0
# 122/1000 epochs... 0
# 123/1000 epochs... 0
# 124/1000 epochs... 0
# 125/1000 epochs... 0
# 126/1000 epochs... 0
# 127/1000 epochs... 0
# 128/1000 epochs... 0
# 129/1000 epochs... 0
# 130/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 98.87%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 131/1000 epochs... 0
# 132/1000 epochs... 0
# 133/1000 epochs... 0
# 134/1000 epochs... 0
# 135/1000 epochs... 0
# 136/1000 epochs... 0
# 137/1000 epochs... 0
# 138/1000 epochs... 0
# 139/1000 epochs... 0
# 140/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 141/1000 epochs... 0
# 142/1000 epochs... 0
# 143/1000 epochs... 0
# 144/1000 epochs... 0
# 145/1000 epochs... 0
# 146/1000 epochs... 0
# 147/1000 epochs... 0
# 148/1000 epochs... 0
# 149/1000 epochs... 0
# 150/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 151/1000 epochs... 0
# 152/1000 epochs... 0
# 153/1000 epochs... 0
# 154/1000 epochs... 0
# 155/1000 epochs... 0
# 156/1000 epochs... 0
# 157/1000 epochs... 0
# 158/1000 epochs... 0
# 159/1000 epochs... 0
# 160/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.24%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 161/1000 epochs... 0
# 162/1000 epochs... 0
# 163/1000 epochs... 0
# 164/1000 epochs... 0
# 165/1000 epochs... 0
# 166/1000 epochs... 0
# 167/1000 epochs... 0
# 168/1000 epochs... 0
# 169/1000 epochs... 0
# 170/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.24%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 171/1000 epochs... 0
# 172/1000 epochs... 0
# 173/1000 epochs... 0
# 174/1000 epochs... 0
# 175/1000 epochs... 0
# 176/1000 epochs... 0
# 177/1000 epochs... 0
# 178/1000 epochs... 0
# 179/1000 epochs... 0
# 180/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.24%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 181/1000 epochs... 0
# 182/1000 epochs... 0
# 183/1000 epochs... 0
# 184/1000 epochs... 0
# 185/1000 epochs... 0
# 186/1000 epochs... 0
# 187/1000 epochs... 0
# 188/1000 epochs... 0
# 189/1000 epochs... 0
# 190/1000 epochs... 0
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 191/1000 epochs... 0
# 192/1000 epochs... 0
# 193/1000 epochs... 0
# 194/1000 epochs... 0
# 195/1000 epochs... 0
# 196/1000 epochs... 0
# 197/1000 epochs... 0
# 198/1000 epochs... 0
# 199/1000 epochs... 0
# tcmalloc: large alloc 1610948608 bytes == 0x1762ca000 @  0x7fb6aaf0f1e7 0x7fb61579ed9a 0x7fb6157a6cd5 0x7fb61508f0c1 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef
# tcmalloc: large alloc 1610948608 bytes == 0x1d631c000 @  0x7fb6aaf0f1e7 0x59203c 0x7fb61508d5bb 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091
# tcmalloc: large alloc 1611022336 bytes == 0x1762ca000 @  0x7fb6aaf0f1e7 0x59203c 0x7fb61031a51d 0x50a635 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x50d356 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13
# Model saved in path: ./saved_model/ja_en/model_s1.ckpt
# 200/1000 epochs... 0
# tcmalloc: large alloc 2710806528 bytes == 0x221d6a000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# Entity:
# For each left:
# Hits@1: 69.50%
# Hits@10: 82.40%
# Hits@50: 88.19%
# Hits@100: 89.96%
# For each right:
# Hits@1: 67.31%
# Hits@10: 82.11%
# Hits@50: 89.60%
# Hits@100: 91.92%
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 98.87%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 201/1000 epochs... 0.55300236
# tcmalloc: large alloc 2710806528 bytes == 0x44935c000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# 202/1000 epochs... 0.55300236
# tcmalloc: large alloc 2710806528 bytes == 0x221d6a000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# 203/1000 epochs... 0.55300236
# tcmalloc: large alloc 2710806528 bytes == 0x221d6a000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# 204/1000 epochs... 0.55300236
# 205/1000 epochs... 0.55300236
# 206/1000 epochs... 0.55300236
# 207/1000 epochs... 0.55300236
# 208/1000 epochs... 0.55300236
# 209/1000 epochs... 0.55300236
# 210/1000 epochs... 0.55300236
# Entity:
# For each left:
# Hits@1: 71.24%
# Hits@10: 84.26%
# Hits@50: 89.47%
# Hits@100: 91.18%
# For each right:
# Hits@1: 68.76%
# Hits@10: 83.36%
# Hits@50: 90.49%
# Hits@100: 92.80%
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.43%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 211/1000 epochs... 0.36209226
# 212/1000 epochs... 0.36209226
# 213/1000 epochs... 0.36209226
# 214/1000 epochs... 0.36209226
# 215/1000 epochs... 0.36209226
# 216/1000 epochs... 0.36209226
# 217/1000 epochs... 0.36209226
# 218/1000 epochs... 0.36209226
# 219/1000 epochs... 0.36209226
# 220/1000 epochs... 0.36209226
# Entity:
# For each left:
# Hits@1: 72.85%
# Hits@10: 85.60%
# Hits@50: 90.65%
# Hits@100: 91.96%
# For each right:
# Hits@1: 69.76%
# Hits@10: 84.34%
# Hits@50: 91.19%
# Hits@100: 93.45%
# Relation:
# For each left:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 98.87%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 221/1000 epochs... 0.2438143
# 222/1000 epochs... 0.2438143
# 223/1000 epochs... 0.2438143
# 224/1000 epochs... 0.2438143
# 225/1000 epochs... 0.2438143
# 226/1000 epochs... 0.2438143
# 227/1000 epochs... 0.2438143
# 228/1000 epochs... 0.2438143
# 229/1000 epochs... 0.2438143
# 230/1000 epochs... 0.2438143
# Entity:
# For each left:
# Hits@1: 73.76%
# Hits@10: 86.54%
# Hits@50: 91.28%
# Hits@100: 92.72%
# For each right:
# Hits@1: 70.28%
# Hits@10: 85.12%
# Hits@50: 91.70%
# Hits@100: 94.05%
# Relation:
# For each left:
# Hits@1: 98.68%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 99.05%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 231/1000 epochs... 0.16958924
# 232/1000 epochs... 0.16958924
# 233/1000 epochs... 0.16958924
# 234/1000 epochs... 0.16958924
# 235/1000 epochs... 0.16958924
# 236/1000 epochs... 0.16958924
# 237/1000 epochs... 0.16958924
# 238/1000 epochs... 0.16958924
# 239/1000 epochs... 0.16958924
# 240/1000 epochs... 0.16958924
# Entity:
# For each left:
# Hits@1: 74.46%
# Hits@10: 87.25%
# Hits@50: 91.83%
# Hits@100: 93.32%
# For each right:
# Hits@1: 70.84%
# Hits@10: 85.70%
# Hits@50: 92.20%
# Hits@100: 94.31%
# Relation:
# For each left:
# Hits@1: 97.35%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 98.30%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 241/1000 epochs... 0.12323475
# 242/1000 epochs... 0.12323475
# 243/1000 epochs... 0.12323475
# 244/1000 epochs... 0.12323475
# 245/1000 epochs... 0.12323475
# 246/1000 epochs... 0.12323475
# 247/1000 epochs... 0.12323475
# 248/1000 epochs... 0.12323475
# 249/1000 epochs... 0.12323475
# 250/1000 epochs... 0.12323475
# Entity:
# For each left:
# Hits@1: 74.85%
# Hits@10: 87.78%
# Hits@50: 92.30%
# Hits@100: 93.74%
# For each right:
# Hits@1: 70.98%
# Hits@10: 86.18%
# Hits@50: 92.47%
# Hits@100: 94.51%
# Relation:
# For each left:
# Hits@1: 96.98%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 97.54%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 251/1000 epochs... 0.09361436
# 252/1000 epochs... 0.09361436
# 253/1000 epochs... 0.09361436
# 254/1000 epochs... 0.09361436
# 255/1000 epochs... 0.09361436
# 256/1000 epochs... 0.09361436
# 257/1000 epochs... 0.09361436
# 258/1000 epochs... 0.09361436
# 259/1000 epochs... 0.09361436
# 260/1000 epochs... 0.09361436
# Entity:
# For each left:
# Hits@1: 75.27%
# Hits@10: 88.04%
# Hits@50: 92.59%
# Hits@100: 94.00%
# For each right:
# Hits@1: 71.17%
# Hits@10: 86.40%
# Hits@50: 92.61%
# Hits@100: 94.69%
# Relation:
# For each left:
# Hits@1: 96.98%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.98%
# Hits@10: 100.00%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 261/1000 epochs... 0.07412377
# 262/1000 epochs... 0.07412377
# 263/1000 epochs... 0.07412377
# 264/1000 epochs... 0.07412377
# 265/1000 epochs... 0.07412377
# 266/1000 epochs... 0.07412377
# 267/1000 epochs... 0.07412377
# 268/1000 epochs... 0.07412377
# 269/1000 epochs... 0.07412377
# 270/1000 epochs... 0.07412377
# Entity:
# For each left:
# Hits@1: 75.52%
# Hits@10: 88.32%
# Hits@50: 92.79%
# Hits@100: 94.18%
# For each right:
# Hits@1: 71.33%
# Hits@10: 86.67%
# Hits@50: 92.80%
# Hits@100: 94.84%
# Relation:
# For each left:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.79%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 271/1000 epochs... 0.06094734
# 272/1000 epochs... 0.06094734
# 273/1000 epochs... 0.06094734
# 274/1000 epochs... 0.06094734
# 275/1000 epochs... 0.06094734
# 276/1000 epochs... 0.06094734
# 277/1000 epochs... 0.06094734
# 278/1000 epochs... 0.06094734
# 279/1000 epochs... 0.06094734
# 280/1000 epochs... 0.06094734
# Entity:
# For each left:
# Hits@1: 75.68%
# Hits@10: 88.61%
# Hits@50: 92.92%
# Hits@100: 94.42%
# For each right:
# Hits@1: 71.46%
# Hits@10: 86.73%
# Hits@50: 92.90%
# Hits@100: 94.90%
# Relation:
# For each left:
# Hits@1: 96.22%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.98%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 281/1000 epochs... 0.051935967
# 282/1000 epochs... 0.051935967
# 283/1000 epochs... 0.051935967
# 284/1000 epochs... 0.051935967
# 285/1000 epochs... 0.051935967
# 286/1000 epochs... 0.051935967
# 287/1000 epochs... 0.051935967
# 288/1000 epochs... 0.051935967
# 289/1000 epochs... 0.051935967
# 290/1000 epochs... 0.051935967
# Entity:
# For each left:
# Hits@1: 75.74%
# Hits@10: 88.73%
# Hits@50: 93.08%
# Hits@100: 94.57%
# For each right:
# Hits@1: 71.50%
# Hits@10: 86.83%
# Hits@50: 92.97%
# Hits@100: 94.94%
# Relation:
# For each left:
# Hits@1: 96.22%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.98%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 291/1000 epochs... 0.04542641
# 292/1000 epochs... 0.04542641
# 293/1000 epochs... 0.04542641
# 294/1000 epochs... 0.04542641
# 295/1000 epochs... 0.04542641
# 296/1000 epochs... 0.04542641
# 297/1000 epochs... 0.04542641
# 298/1000 epochs... 0.04542641
# 299/1000 epochs... 0.04542641
# 300/1000 epochs... 0.04542641
# Entity:
# For each left:
# Hits@1: 75.78%
# Hits@10: 88.84%
# Hits@50: 93.23%
# Hits@100: 94.66%
# For each right:
# Hits@1: 71.50%
# Hits@10: 86.96%
# Hits@50: 93.01%
# Hits@100: 95.00%
# Relation:
# For each left:
# Hits@1: 96.03%
# Hits@10: 99.62%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 97.35%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 301/1000 epochs... 0.040597934
# 302/1000 epochs... 0.040597934
# 303/1000 epochs... 0.040597934
# 304/1000 epochs... 0.040597934
# 305/1000 epochs... 0.040597934
# 306/1000 epochs... 0.040597934
# 307/1000 epochs... 0.040597934
# 308/1000 epochs... 0.040597934
# 309/1000 epochs... 0.040597934
# 310/1000 epochs... 0.040597934
# Entity:
# For each left:
# Hits@1: 75.90%
# Hits@10: 88.91%
# Hits@50: 93.29%
# Hits@100: 94.73%
# For each right:
# Hits@1: 71.56%
# Hits@10: 86.96%
# Hits@50: 93.08%
# Hits@100: 95.07%
# Relation:
# For each left:
# Hits@1: 96.03%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.98%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 311/1000 epochs... 0.037260346
# 312/1000 epochs... 0.037260346
# 313/1000 epochs... 0.037260346
# 314/1000 epochs... 0.037260346
# 315/1000 epochs... 0.037260346
# 316/1000 epochs... 0.037260346
# 317/1000 epochs... 0.037260346
# 318/1000 epochs... 0.037260346
# 319/1000 epochs... 0.037260346
# 320/1000 epochs... 0.037260346
# Entity:
# For each left:
# Hits@1: 76.01%
# Hits@10: 89.05%
# Hits@50: 93.37%
# Hits@100: 94.82%
# For each right:
# Hits@1: 71.65%
# Hits@10: 87.03%
# Hits@50: 93.10%
# Hits@100: 95.07%
# Relation:
# For each left:
# Hits@1: 95.84%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.79%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 321/1000 epochs... 0.034966037
# 322/1000 epochs... 0.034966037
# 323/1000 epochs... 0.034966037
# 324/1000 epochs... 0.034966037
# 325/1000 epochs... 0.034966037
# 326/1000 epochs... 0.034966037
# 327/1000 epochs... 0.034966037
# 328/1000 epochs... 0.034966037
# 329/1000 epochs... 0.034966037
# 330/1000 epochs... 0.034966037
# Entity:
# For each left:
# Hits@1: 76.13%
# Hits@10: 89.12%
# Hits@50: 93.47%
# Hits@100: 94.85%
# For each right:
# Hits@1: 71.73%
# Hits@10: 87.09%
# Hits@50: 93.12%
# Hits@100: 95.10%
# Relation:
# For each left:
# Hits@1: 95.09%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 331/1000 epochs... 0.03334904
# 332/1000 epochs... 0.03334904
# 333/1000 epochs... 0.03334904
# 334/1000 epochs... 0.03334904
# 335/1000 epochs... 0.03334904
# 336/1000 epochs... 0.03334904
# 337/1000 epochs... 0.03334904
# 338/1000 epochs... 0.03334904
# 339/1000 epochs... 0.03334904
# 340/1000 epochs... 0.03334904
# Entity:
# For each left:
# Hits@1: 76.17%
# Hits@10: 89.16%
# Hits@50: 93.53%
# Hits@100: 94.92%
# For each right:
# Hits@1: 71.85%
# Hits@10: 87.11%
# Hits@50: 93.13%
# Hits@100: 95.11%
# Relation:
# For each left:
# Hits@1: 95.09%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 341/1000 epochs... 0.032092687
# 342/1000 epochs... 0.032092687
# 343/1000 epochs... 0.032092687
# 344/1000 epochs... 0.032092687
# 345/1000 epochs... 0.032092687
# 346/1000 epochs... 0.032092687
# 347/1000 epochs... 0.032092687
# 348/1000 epochs... 0.032092687
# 349/1000 epochs... 0.032092687
# 350/1000 epochs... 0.032092687
# Entity:
# For each left:
# Hits@1: 76.20%
# Hits@10: 89.16%
# Hits@50: 93.59%
# Hits@100: 95.01%
# For each right:
# Hits@1: 71.96%
# Hits@10: 87.12%
# Hits@50: 93.19%
# Hits@100: 95.11%
# Relation:
# For each left:
# Hits@1: 95.09%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 351/1000 epochs... 0.031074049
# 352/1000 epochs... 0.031074049
# 353/1000 epochs... 0.031074049
# 354/1000 epochs... 0.031074049
# 355/1000 epochs... 0.031074049
# 356/1000 epochs... 0.031074049
# 357/1000 epochs... 0.031074049
# 358/1000 epochs... 0.031074049
# 359/1000 epochs... 0.031074049
# 360/1000 epochs... 0.031074049
# Entity:
# For each left:
# Hits@1: 76.17%
# Hits@10: 89.23%
# Hits@50: 93.67%
# Hits@100: 95.03%
# For each right:
# Hits@1: 71.97%
# Hits@10: 87.21%
# Hits@50: 93.19%
# Hits@100: 95.13%
# Relation:
# For each left:
# Hits@1: 95.09%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 361/1000 epochs... 0.030223444
# 362/1000 epochs... 0.030223444
# 363/1000 epochs... 0.030223444
# 364/1000 epochs... 0.030223444
# 365/1000 epochs... 0.030223444
# 366/1000 epochs... 0.030223444
# 367/1000 epochs... 0.030223444
# 368/1000 epochs... 0.030223444
# 369/1000 epochs... 0.030223444
# 370/1000 epochs... 0.030223444
# Entity:
# For each left:
# Hits@1: 76.23%
# Hits@10: 89.26%
# Hits@50: 93.72%
# Hits@100: 95.05%
# For each right:
# Hits@1: 72.03%
# Hits@10: 87.29%
# Hits@50: 93.25%
# Hits@100: 95.18%
# Relation:
# For each left:
# Hits@1: 94.90%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 371/1000 epochs... 0.029541451
# 372/1000 epochs... 0.029541451
# 373/1000 epochs... 0.029541451
# 374/1000 epochs... 0.029541451
# 375/1000 epochs... 0.029541451
# 376/1000 epochs... 0.029541451
# 377/1000 epochs... 0.029541451
# 378/1000 epochs... 0.029541451
# 379/1000 epochs... 0.029541451
# 380/1000 epochs... 0.029541451
# Entity:
# For each left:
# Hits@1: 76.27%
# Hits@10: 89.29%
# Hits@50: 93.72%
# Hits@100: 95.05%
# For each right:
# Hits@1: 72.09%
# Hits@10: 87.40%
# Hits@50: 93.30%
# Hits@100: 95.17%
# Relation:
# For each left:
# Hits@1: 94.90%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.79%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 381/1000 epochs... 0.028960219
# 382/1000 epochs... 0.028960219
# 383/1000 epochs... 0.028960219
# 384/1000 epochs... 0.028960219
# 385/1000 epochs... 0.028960219
# 386/1000 epochs... 0.028960219
# 387/1000 epochs... 0.028960219
# 388/1000 epochs... 0.028960219
# 389/1000 epochs... 0.028960219
# 390/1000 epochs... 0.028960219
# Entity:
# For each left:
# Hits@1: 76.31%
# Hits@10: 89.31%
# Hits@50: 93.74%
# Hits@100: 95.07%
# For each right:
# Hits@1: 72.10%
# Hits@10: 87.45%
# Hits@50: 93.32%
# Hits@100: 95.19%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.79%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 391/1000 epochs... 0.028440073
# 392/1000 epochs... 0.028440073
# 393/1000 epochs... 0.028440073
# 394/1000 epochs... 0.028440073
# 395/1000 epochs... 0.028440073
# 396/1000 epochs... 0.028440073
# 397/1000 epochs... 0.028440073
# 398/1000 epochs... 0.028440073
# 399/1000 epochs... 0.028440073
# 400/1000 epochs... 0.028440073
# Entity:
# For each left:
# Hits@1: 76.28%
# Hits@10: 89.31%
# Hits@50: 93.72%
# Hits@100: 95.09%
# For each right:
# Hits@1: 72.21%
# Hits@10: 87.52%
# Hits@50: 93.37%
# Hits@100: 95.21%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.24%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.41%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 401/1000 epochs... 0.027971463
# 402/1000 epochs... 0.027971463
# 403/1000 epochs... 0.027971463
# 404/1000 epochs... 0.027971463
# 405/1000 epochs... 0.027971463
# 406/1000 epochs... 0.027971463
# 407/1000 epochs... 0.027971463
# 408/1000 epochs... 0.027971463
# 409/1000 epochs... 0.027971463
# 410/1000 epochs... 0.027971463
# Entity:
# For each left:
# Hits@1: 76.26%
# Hits@10: 89.33%
# Hits@50: 93.75%
# Hits@100: 95.09%
# For each right:
# Hits@1: 72.24%
# Hits@10: 87.50%
# Hits@50: 93.38%
# Hits@100: 95.22%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.81%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.22%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 411/1000 epochs... 0.027551902
# 412/1000 epochs... 0.027551902
# 413/1000 epochs... 0.027551902
# 414/1000 epochs... 0.027551902
# 415/1000 epochs... 0.027551902
# 416/1000 epochs... 0.027551902
# 417/1000 epochs... 0.027551902
# 418/1000 epochs... 0.027551902
# 419/1000 epochs... 0.027551902
# 420/1000 epochs... 0.027551902
# Entity:
# For each left:
# Hits@1: 76.28%
# Hits@10: 89.34%
# Hits@50: 93.77%
# Hits@100: 95.06%
# For each right:
# Hits@1: 72.27%
# Hits@10: 87.51%
# Hits@50: 93.39%
# Hits@100: 95.23%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 100.00%
# For each right:
# Hits@1: 96.41%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 421/1000 epochs... 0.027167976
# 422/1000 epochs... 0.027167976
# 423/1000 epochs... 0.027167976
# 424/1000 epochs... 0.027167976
# 425/1000 epochs... 0.027167976
# 426/1000 epochs... 0.027167976
# 427/1000 epochs... 0.027167976
# 428/1000 epochs... 0.027167976
# 429/1000 epochs... 0.027167976
# 430/1000 epochs... 0.027167976
# Entity:
# For each left:
# Hits@1: 76.32%
# Hits@10: 89.37%
# Hits@50: 93.79%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.26%
# Hits@10: 87.54%
# Hits@50: 93.40%
# Hits@100: 95.23%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 96.22%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 431/1000 epochs... 0.026811654
# 432/1000 epochs... 0.026811654
# 433/1000 epochs... 0.026811654
# 434/1000 epochs... 0.026811654
# 435/1000 epochs... 0.026811654
# 436/1000 epochs... 0.026811654
# 437/1000 epochs... 0.026811654
# 438/1000 epochs... 0.026811654
# 439/1000 epochs... 0.026811654
# 440/1000 epochs... 0.026811654
# Entity:
# For each left:
# Hits@1: 76.39%
# Hits@10: 89.41%
# Hits@50: 93.79%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.33%
# Hits@10: 87.63%
# Hits@50: 93.39%
# Hits@100: 95.28%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 96.22%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 441/1000 epochs... 0.026479555
# 442/1000 epochs... 0.026479555
# 443/1000 epochs... 0.026479555
# 444/1000 epochs... 0.026479555
# 445/1000 epochs... 0.026479555
# 446/1000 epochs... 0.026479555
# 447/1000 epochs... 0.026479555
# 448/1000 epochs... 0.026479555
# 449/1000 epochs... 0.026479555
# 450/1000 epochs... 0.026479555
# Entity:
# For each left:
# Hits@1: 76.44%
# Hits@10: 89.42%
# Hits@50: 93.82%
# Hits@100: 95.12%
# For each right:
# Hits@1: 72.41%
# Hits@10: 87.65%
# Hits@50: 93.39%
# Hits@100: 95.28%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 96.03%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 451/1000 epochs... 0.026168501
# 452/1000 epochs... 0.026168501
# 453/1000 epochs... 0.026168501
# 454/1000 epochs... 0.026168501
# 455/1000 epochs... 0.026168501
# 456/1000 epochs... 0.026168501
# 457/1000 epochs... 0.026168501
# 458/1000 epochs... 0.026168501
# 459/1000 epochs... 0.026168501
# 460/1000 epochs... 0.026168501
# Entity:
# For each left:
# Hits@1: 76.46%
# Hits@10: 89.46%
# Hits@50: 93.83%
# Hits@100: 95.12%
# For each right:
# Hits@1: 72.45%
# Hits@10: 87.70%
# Hits@50: 93.40%
# Hits@100: 95.28%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 96.03%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 461/1000 epochs... 0.025875062
# 462/1000 epochs... 0.025875062
# 463/1000 epochs... 0.025875062
# 464/1000 epochs... 0.025875062
# 465/1000 epochs... 0.025875062
# 466/1000 epochs... 0.025875062
# 467/1000 epochs... 0.025875062
# 468/1000 epochs... 0.025875062
# 469/1000 epochs... 0.025875062
# 470/1000 epochs... 0.025875062
# Entity:
# For each left:
# Hits@1: 76.48%
# Hits@10: 89.50%
# Hits@50: 93.86%
# Hits@100: 95.11%
# For each right:
# Hits@1: 72.45%
# Hits@10: 87.70%
# Hits@50: 93.39%
# Hits@100: 95.30%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 471/1000 epochs... 0.02559656
# 472/1000 epochs... 0.02559656
# 473/1000 epochs... 0.02559656
# 474/1000 epochs... 0.02559656
# 475/1000 epochs... 0.02559656
# 476/1000 epochs... 0.02559656
# 477/1000 epochs... 0.02559656
# 478/1000 epochs... 0.02559656
# 479/1000 epochs... 0.02559656
# 480/1000 epochs... 0.02559656
# Entity:
# For each left:
# Hits@1: 76.46%
# Hits@10: 89.49%
# Hits@50: 93.86%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.43%
# Hits@10: 87.70%
# Hits@50: 93.42%
# Hits@100: 95.29%
# Relation:
# For each left:
# Hits@1: 94.90%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 481/1000 epochs... 0.025332076
# 482/1000 epochs... 0.025332076
# 483/1000 epochs... 0.025332076
# 484/1000 epochs... 0.025332076
# 485/1000 epochs... 0.025332076
# 486/1000 epochs... 0.025332076
# 487/1000 epochs... 0.025332076
# 488/1000 epochs... 0.025332076
# 489/1000 epochs... 0.025332076
# 490/1000 epochs... 0.025332076
# Entity:
# For each left:
# Hits@1: 76.47%
# Hits@10: 89.54%
# Hits@50: 93.88%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.45%
# Hits@10: 87.70%
# Hits@50: 93.45%
# Hits@100: 95.30%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.81%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 491/1000 epochs... 0.025080068
# 492/1000 epochs... 0.025080068
# 493/1000 epochs... 0.025080068
# 494/1000 epochs... 0.025080068
# 495/1000 epochs... 0.025080068
# 496/1000 epochs... 0.025080068
# 497/1000 epochs... 0.025080068
# 498/1000 epochs... 0.025080068
# 499/1000 epochs... 0.025080068
# 500/1000 epochs... 0.025080068
# Entity:
# For each left:
# Hits@1: 76.49%
# Hits@10: 89.55%
# Hits@50: 93.90%
# Hits@100: 95.11%
# For each right:
# Hits@1: 72.50%
# Hits@10: 87.71%
# Hits@50: 93.47%
# Hits@100: 95.31%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 501/1000 epochs... 0.024840489
# 502/1000 epochs... 0.024840489
# 503/1000 epochs... 0.024840489
# 504/1000 epochs... 0.024840489
# 505/1000 epochs... 0.024840489
# 506/1000 epochs... 0.024840489
# 507/1000 epochs... 0.024840489
# 508/1000 epochs... 0.024840489
# 509/1000 epochs... 0.024840489
# 510/1000 epochs... 0.024840489
# Entity:
# For each left:
# Hits@1: 76.51%
# Hits@10: 89.57%
# Hits@50: 93.89%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.54%
# Hits@10: 87.70%
# Hits@50: 93.48%
# Hits@100: 95.31%
# Relation:
# For each left:
# Hits@1: 94.71%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 511/1000 epochs... 0.024612065
# 512/1000 epochs... 0.024612065
# 513/1000 epochs... 0.024612065
# 514/1000 epochs... 0.024612065
# 515/1000 epochs... 0.024612065
# 516/1000 epochs... 0.024612065
# 517/1000 epochs... 0.024612065
# 518/1000 epochs... 0.024612065
# 519/1000 epochs... 0.024612065
# 520/1000 epochs... 0.024612065
# Entity:
# For each left:
# Hits@1: 76.53%
# Hits@10: 89.61%
# Hits@50: 93.88%
# Hits@100: 95.10%
# For each right:
# Hits@1: 72.57%
# Hits@10: 87.70%
# Hits@50: 93.52%
# Hits@100: 95.33%
# Relation:
# For each left:
# Hits@1: 94.52%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.84%
# Hits@10: 99.81%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 521/1000 epochs... 0.024394
# 522/1000 epochs... 0.024394
# 523/1000 epochs... 0.024394
# 524/1000 epochs... 0.024394
# 525/1000 epochs... 0.024394
# 526/1000 epochs... 0.024394
# 527/1000 epochs... 0.024394
# 528/1000 epochs... 0.024394
# 529/1000 epochs... 0.024394
# 530/1000 epochs... 0.024394
# Entity:
# For each left:
# Hits@1: 76.50%
# Hits@10: 89.66%
# Hits@50: 93.89%
# Hits@100: 95.11%
# For each right:
# Hits@1: 72.56%
# Hits@10: 87.72%
# Hits@50: 93.53%
# Hits@100: 95.31%
# Relation:
# For each left:
# Hits@1: 94.33%
# Hits@10: 99.05%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.84%
# Hits@10: 99.43%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 531/1000 epochs... 0.024185615
# 532/1000 epochs... 0.024185615
# 533/1000 epochs... 0.024185615
# 534/1000 epochs... 0.024185615
# 535/1000 epochs... 0.024185615
# 536/1000 epochs... 0.024185615
# 537/1000 epochs... 0.024185615
# 538/1000 epochs... 0.024185615
# 539/1000 epochs... 0.024185615
# 540/1000 epochs... 0.024185615
# Entity:
# For each left:
# Hits@1: 76.50%
# Hits@10: 89.70%
# Hits@50: 93.87%
# Hits@100: 95.12%
# For each right:
# Hits@1: 72.53%
# Hits@10: 87.76%
# Hits@50: 93.54%
# Hits@100: 95.32%
# Relation:
# For each left:
# Hits@1: 94.33%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.84%
# Hits@10: 99.43%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 541/1000 epochs... 0.023986097
# 542/1000 epochs... 0.023986097
# 543/1000 epochs... 0.023986097
# 544/1000 epochs... 0.023986097
# 545/1000 epochs... 0.023986097
# 546/1000 epochs... 0.023986097
# 547/1000 epochs... 0.023986097
# 548/1000 epochs... 0.023986097
# 549/1000 epochs... 0.023986097
# 550/1000 epochs... 0.023986097
# Entity:
# For each left:
# Hits@1: 76.49%
# Hits@10: 89.69%
# Hits@50: 93.86%
# Hits@100: 95.12%
# For each right:
# Hits@1: 72.56%
# Hits@10: 87.75%
# Hits@50: 93.52%
# Hits@100: 95.33%
# Relation:
# For each left:
# Hits@1: 94.33%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.84%
# Hits@10: 99.43%
# Hits@50: 100.00%
# Hits@100: 100.00%
# 551/1000 epochs... 0.023795176
# 552/1000 epochs... 0.023795176
# 553/1000 epochs... 0.023795176
# 554/1000 epochs... 0.023795176
# 555/1000 epochs... 0.023795176
# 556/1000 epochs... 0.023795176
# 557/1000 epochs... 0.023795176
# 558/1000 epochs... 0.023795176
# 559/1000 epochs... 0.023795176
# 560/1000 epochs... 0.023795176
# Entity:
# For each left:
# Hits@1: 76.48%
# Hits@10: 89.69%
# Hits@50: 93.86%
# Hits@100: 95.16%
# For each right:
# Hits@1: 72.64%
# Hits@10: 87.76%
# Hits@50: 93.53%
# Hits@100: 95.31%
# Relation:
# For each left:
# Hits@1: 94.33%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 100.00%
# 561/1000 epochs... 0.023611857
# 562/1000 epochs... 0.023611857
# 563/1000 epochs... 0.023611857
# 564/1000 epochs... 0.023611857
# 565/1000 epochs... 0.023611857
# 566/1000 epochs... 0.023611857
# 567/1000 epochs... 0.023611857
# 568/1000 epochs... 0.023611857
# 569/1000 epochs... 0.023611857
# 570/1000 epochs... 0.023611857
# Entity:
# For each left:
# Hits@1: 76.43%
# Hits@10: 89.71%
# Hits@50: 93.86%
# Hits@100: 95.18%
# For each right:
# Hits@1: 72.61%
# Hits@10: 87.77%
# Hits@50: 93.52%
# Hits@100: 95.32%
# Relation:
# For each left:
# Hits@1: 94.14%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 100.00%
# 571/1000 epochs... 0.023435526
# 572/1000 epochs... 0.023435526
# 573/1000 epochs... 0.023435526
# 574/1000 epochs... 0.023435526
# 575/1000 epochs... 0.023435526
# 576/1000 epochs... 0.023435526
# 577/1000 epochs... 0.023435526
# 578/1000 epochs... 0.023435526
# 579/1000 epochs... 0.023435526
# 580/1000 epochs... 0.023435526
# Entity:
# For each left:
# Hits@1: 76.45%
# Hits@10: 89.71%
# Hits@50: 93.88%
# Hits@100: 95.22%
# For each right:
# Hits@1: 72.63%
# Hits@10: 87.77%
# Hits@50: 93.55%
# Hits@100: 95.33%
# Relation:
# For each left:
# Hits@1: 94.14%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 99.81%
# 581/1000 epochs... 0.02326615
# 582/1000 epochs... 0.02326615
# 583/1000 epochs... 0.02326615
# 584/1000 epochs... 0.02326615
# 585/1000 epochs... 0.02326615
# 586/1000 epochs... 0.02326615
# 587/1000 epochs... 0.02326615
# 588/1000 epochs... 0.02326615
# 589/1000 epochs... 0.02326615
# 590/1000 epochs... 0.02326615
# Entity:
# For each left:
# Hits@1: 76.47%
# Hits@10: 89.74%
# Hits@50: 93.88%
# Hits@100: 95.23%
# For each right:
# Hits@1: 72.64%
# Hits@10: 87.80%
# Hits@50: 93.60%
# Hits@100: 95.34%
# Relation:
# For each left:
# Hits@1: 93.95%
# Hits@10: 98.87%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 95.65%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 99.81%
# 591/1000 epochs... 0.023102976
# 592/1000 epochs... 0.023102976
# 593/1000 epochs... 0.023102976
# 594/1000 epochs... 0.023102976
# 595/1000 epochs... 0.023102976
# 596/1000 epochs... 0.023102976
# 597/1000 epochs... 0.023102976
# 598/1000 epochs... 0.023102976
# 599/1000 epochs... 0.023102976
# Model saved in path: ./saved_model/ja_en/model_s2.ckpt
# 600/1000 epochs... 0.023102976
# 2020-06-01 10:40:45.591890: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x5b2fc2000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# Entity:
# For each left:
# Hits@1: 55.99%
# Hits@10: 74.11%
# Hits@50: 84.06%
# Hits@100: 87.33%
# For each right:
# Hits@1: 56.38%
# Hits@10: 75.73%
# Hits@50: 85.10%
# Hits@100: 88.79%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 99.24%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 99.81%
# 601/1000 epochs... 0.5807987
# 2020-06-01 10:42:22.503560: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x5a6c68000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# 602/1000 epochs... 0.5807987
# 2020-06-01 10:42:26.606790: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x5a6c68000 @  0x7fb6aaef1b6b 0x7fb6aaf11379 0x7fb612109977 0x7fb611ef708f 0x7fb611dbc42b 0x7fb611d81e16 0x7fb611d82ca3 0x7fb611d82e77 0x7fb615919b33 0x7fb61203b136 0x7fb61202d785 0x7fb6120eb8b9 0x7fb6120e8f88 0x7fb6a97f16df 0x7fb6aa8d36db 0x7fb6aac0c88f
# 603/1000 epochs... 0.5807987
# 2020-06-01 10:42:29.829607: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# 604/1000 epochs... 0.5807987
# 2020-06-01 10:42:33.059962: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# 605/1000 epochs... 0.5807987
# 606/1000 epochs... 0.5807987
# 607/1000 epochs... 0.5807987
# 608/1000 epochs... 0.5807987
# 609/1000 epochs... 0.5807987
# 610/1000 epochs... 0.5807987
# Entity:
# For each left:
# Hits@1: 70.27%
# Hits@10: 86.78%
# Hits@50: 93.16%
# Hits@100: 95.25%
# For each right:
# Hits@1: 65.85%
# Hits@10: 84.70%
# Hits@50: 92.04%
# Hits@100: 94.19%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 98.49%
# Hits@50: 99.05%
# Hits@100: 99.24%
# For each right:
# Hits@1: 93.01%
# Hits@10: 97.73%
# Hits@50: 98.68%
# Hits@100: 99.43%
# 611/1000 epochs... 0.11583245
# 612/1000 epochs... 0.11583245
# 613/1000 epochs... 0.11583245
# 614/1000 epochs... 0.11583245
# 615/1000 epochs... 0.11583245
# 616/1000 epochs... 0.11583245
# 617/1000 epochs... 0.11583245
# 618/1000 epochs... 0.11583245
# 619/1000 epochs... 0.11583245
# 620/1000 epochs... 0.11583245
# Entity:
# For each left:
# Hits@1: 72.64%
# Hits@10: 88.56%
# Hits@50: 94.18%
# Hits@100: 96.03%
# For each right:
# Hits@1: 67.02%
# Hits@10: 85.70%
# Hits@50: 92.66%
# Hits@100: 94.70%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 98.68%
# Hits@50: 99.05%
# Hits@100: 99.05%
# For each right:
# Hits@1: 92.63%
# Hits@10: 97.35%
# Hits@50: 98.68%
# Hits@100: 99.24%
# 621/1000 epochs... 0.063111275
# 622/1000 epochs... 0.063111275
# 623/1000 epochs... 0.063111275
# 624/1000 epochs... 0.063111275
# 625/1000 epochs... 0.063111275
# 626/1000 epochs... 0.063111275
# 627/1000 epochs... 0.063111275
# 628/1000 epochs... 0.063111275
# 629/1000 epochs... 0.063111275
# 630/1000 epochs... 0.063111275
# Entity:
# For each left:
# Hits@1: 73.93%
# Hits@10: 89.50%
# Hits@50: 94.73%
# Hits@100: 96.41%
# For each right:
# Hits@1: 68.48%
# Hits@10: 86.58%
# Hits@50: 93.18%
# Hits@100: 95.20%
# Relation:
# For each left:
# Hits@1: 95.46%
# Hits@10: 98.49%
# Hits@50: 99.24%
# Hits@100: 99.43%
# For each right:
# Hits@1: 90.74%
# Hits@10: 96.03%
# Hits@50: 98.30%
# Hits@100: 99.24%
# 631/1000 epochs... 0.04669043
# 632/1000 epochs... 0.04669043
# 633/1000 epochs... 0.04669043
# 634/1000 epochs... 0.04669043
# 635/1000 epochs... 0.04669043
# 636/1000 epochs... 0.04669043
# 637/1000 epochs... 0.04669043
# 638/1000 epochs... 0.04669043
# 639/1000 epochs... 0.04669043
# 640/1000 epochs... 0.04669043

# %%
# last 400 epochs
# !python main.py
# Out:
# WARNING:tensorflow:From main.py:18: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loading a file...data/ja_en/ent_ids_1
# loading a file...data/ja_en/ent_ids_2
# loading a file...data/ja_en/shuffled_ref_ent_ids
# loading a file...data/ja_en/ref_r_ids
# loading a file...data/ja_en/triples_1
# loading a file...data/ja_en/triples_2
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:263: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# adding the primal input layer...
# 39594 rows, 300 columns.
# getting a sparse tensor...
# tcmalloc: large alloc 12541485056 bytes == 0x1a6cc000 @  0x7fd6f0d52001 0x7fd6ee1cd765 0x7fd6ee231bb0 0x7fd6ee233a4f 0x7fd6ee2ca048 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fd6f094db97 0x5b250a
# calculate relation representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Init.py:17: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# first interaction...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:107: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# adding sparse attention layer...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:114: The name tf.sparse_softmax is deprecated. Please use tf.sparse.softmax instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:115: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# second interaction...
# adding sparse attention layer...
# getting loss...
# gcn layers...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:84: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# adding a diag layer...
# adding a diag layer...
# calculate joint entity representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:297: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# getting loss...
# getting loss...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:326: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# initializing...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:330: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:331: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-06-01 13:21:57.227588: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-01 13:21:57.277920: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-06-01 13:21:57.277983: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (eaacb5044871): /proc/driver/nvidia/version does not exist
# 2020-06-01 13:21:57.292276: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-06-01 13:21:57.294937: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2964bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 13:21:57.294979: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# running...
# Model restore from path: None
# 1/1000 epochs... 0
# 2/1000 epochs... 0
# 3/1000 epochs... 0
# 4/1000 epochs... 0
# 5/1000 epochs... 0
# 6/1000 epochs... 0
# 7/1000 epochs... 0
# 8/1000 epochs... 0
# 9/1000 epochs... 0
# 10/1000 epochs... 0
# 11/1000 epochs... 0
# 12/1000 epochs... 0
# 13/1000 epochs... 0
# 14/1000 epochs... 0
# 15/1000 epochs... 0
# 16/1000 epochs... 0
# 17/1000 epochs... 0
# 18/1000 epochs... 0
# 19/1000 epochs... 0
# 20/1000 epochs... 0
# 21/1000 epochs... 0
# 22/1000 epochs... 0
# 23/1000 epochs... 0
# 24/1000 epochs... 0
# 25/1000 epochs... 0
# 26/1000 epochs... 0
# 27/1000 epochs... 0
# 28/1000 epochs... 0
# 29/1000 epochs... 0
# 30/1000 epochs... 0
# 31/1000 epochs... 0
# 32/1000 epochs... 0
# 33/1000 epochs... 0
# 34/1000 epochs... 0
# 35/1000 epochs... 0
# 36/1000 epochs... 0
# 37/1000 epochs... 0
# 38/1000 epochs... 0
# 39/1000 epochs... 0
# 40/1000 epochs... 0
# 41/1000 epochs... 0
# 42/1000 epochs... 0
# 43/1000 epochs... 0
# 44/1000 epochs... 0
# 45/1000 epochs... 0
# 46/1000 epochs... 0
# 47/1000 epochs... 0
# 48/1000 epochs... 0
# 49/1000 epochs... 0
# 50/1000 epochs... 0
# 51/1000 epochs... 0
# 52/1000 epochs... 0
# 53/1000 epochs... 0
# 54/1000 epochs... 0
# 55/1000 epochs... 0
# 56/1000 epochs... 0
# 57/1000 epochs... 0
# 58/1000 epochs... 0
# 59/1000 epochs... 0
# 60/1000 epochs... 0
# 61/1000 epochs... 0
# 62/1000 epochs... 0
# 63/1000 epochs... 0
# 64/1000 epochs... 0
# 65/1000 epochs... 0
# 66/1000 epochs... 0
# 67/1000 epochs... 0
# 68/1000 epochs... 0
# 69/1000 epochs... 0
# 70/1000 epochs... 0
# 71/1000 epochs... 0
# 72/1000 epochs... 0
# 73/1000 epochs... 0
# 74/1000 epochs... 0
# 75/1000 epochs... 0
# 76/1000 epochs... 0
# 77/1000 epochs... 0
# 78/1000 epochs... 0
# 79/1000 epochs... 0
# 80/1000 epochs... 0
# 81/1000 epochs... 0
# 82/1000 epochs... 0
# 83/1000 epochs... 0
# 84/1000 epochs... 0
# 85/1000 epochs... 0
# 86/1000 epochs... 0
# 87/1000 epochs... 0
# 88/1000 epochs... 0
# 89/1000 epochs... 0
# 90/1000 epochs... 0
# 91/1000 epochs... 0
# 92/1000 epochs... 0
# 93/1000 epochs... 0
# 94/1000 epochs... 0
# 95/1000 epochs... 0
# 96/1000 epochs... 0
# 97/1000 epochs... 0
# 98/1000 epochs... 0
# 99/1000 epochs... 0
# 100/1000 epochs... 0
# 101/1000 epochs... 0
# 102/1000 epochs... 0
# 103/1000 epochs... 0
# 104/1000 epochs... 0
# 105/1000 epochs... 0
# 106/1000 epochs... 0
# 107/1000 epochs... 0
# 108/1000 epochs... 0
# 109/1000 epochs... 0
# 110/1000 epochs... 0
# 111/1000 epochs... 0
# 112/1000 epochs... 0
# 113/1000 epochs... 0
# 114/1000 epochs... 0
# 115/1000 epochs... 0
# 116/1000 epochs... 0
# 117/1000 epochs... 0
# 118/1000 epochs... 0
# 119/1000 epochs... 0
# 120/1000 epochs... 0
# 121/1000 epochs... 0
# 122/1000 epochs... 0
# 123/1000 epochs... 0
# 124/1000 epochs... 0
# 125/1000 epochs... 0
# 126/1000 epochs... 0
# 127/1000 epochs... 0
# 128/1000 epochs... 0
# 129/1000 epochs... 0
# 130/1000 epochs... 0
# 131/1000 epochs... 0
# 132/1000 epochs... 0
# 133/1000 epochs... 0
# 134/1000 epochs... 0
# 135/1000 epochs... 0
# 136/1000 epochs... 0
# 137/1000 epochs... 0
# 138/1000 epochs... 0
# 139/1000 epochs... 0
# 140/1000 epochs... 0
# 141/1000 epochs... 0
# 142/1000 epochs... 0
# 143/1000 epochs... 0
# 144/1000 epochs... 0
# 145/1000 epochs... 0
# 146/1000 epochs... 0
# 147/1000 epochs... 0
# 148/1000 epochs... 0
# 149/1000 epochs... 0
# 150/1000 epochs... 0
# 151/1000 epochs... 0
# 152/1000 epochs... 0
# 153/1000 epochs... 0
# 154/1000 epochs... 0
# 155/1000 epochs... 0
# 156/1000 epochs... 0
# 157/1000 epochs... 0
# 158/1000 epochs... 0
# 159/1000 epochs... 0
# 160/1000 epochs... 0
# 161/1000 epochs... 0
# 162/1000 epochs... 0
# 163/1000 epochs... 0
# 164/1000 epochs... 0
# 165/1000 epochs... 0
# 166/1000 epochs... 0
# 167/1000 epochs... 0
# 168/1000 epochs... 0
# 169/1000 epochs... 0
# 170/1000 epochs... 0
# 171/1000 epochs... 0
# 172/1000 epochs... 0
# 173/1000 epochs... 0
# 174/1000 epochs... 0
# 175/1000 epochs... 0
# 176/1000 epochs... 0
# 177/1000 epochs... 0
# 178/1000 epochs... 0
# 179/1000 epochs... 0
# 180/1000 epochs... 0
# 181/1000 epochs... 0
# 182/1000 epochs... 0
# 183/1000 epochs... 0
# 184/1000 epochs... 0
# 185/1000 epochs... 0
# 186/1000 epochs... 0
# 187/1000 epochs... 0
# 188/1000 epochs... 0
# 189/1000 epochs... 0
# 190/1000 epochs... 0
# 191/1000 epochs... 0
# 192/1000 epochs... 0
# 193/1000 epochs... 0
# 194/1000 epochs... 0
# 195/1000 epochs... 0
# 196/1000 epochs... 0
# 197/1000 epochs... 0
# 198/1000 epochs... 0
# 199/1000 epochs... 0
# 200/1000 epochs... 0
# 201/1000 epochs... 0
# 202/1000 epochs... 0
# 203/1000 epochs... 0
# 204/1000 epochs... 0
# 205/1000 epochs... 0
# 206/1000 epochs... 0
# 207/1000 epochs... 0
# 208/1000 epochs... 0
# 209/1000 epochs... 0
# 210/1000 epochs... 0
# 211/1000 epochs... 0
# 212/1000 epochs... 0
# 213/1000 epochs... 0
# 214/1000 epochs... 0
# 215/1000 epochs... 0
# 216/1000 epochs... 0
# 217/1000 epochs... 0
# 218/1000 epochs... 0
# 219/1000 epochs... 0
# 220/1000 epochs... 0
# 221/1000 epochs... 0
# 222/1000 epochs... 0
# 223/1000 epochs... 0
# 224/1000 epochs... 0
# 225/1000 epochs... 0
# 226/1000 epochs... 0
# 227/1000 epochs... 0
# 228/1000 epochs... 0
# 229/1000 epochs... 0
# 230/1000 epochs... 0
# 231/1000 epochs... 0
# 232/1000 epochs... 0
# 233/1000 epochs... 0
# 234/1000 epochs... 0
# 235/1000 epochs... 0
# 236/1000 epochs... 0
# 237/1000 epochs... 0
# 238/1000 epochs... 0
# 239/1000 epochs... 0
# 240/1000 epochs... 0
# 241/1000 epochs... 0
# 242/1000 epochs... 0
# 243/1000 epochs... 0
# 244/1000 epochs... 0
# 245/1000 epochs... 0
# 246/1000 epochs... 0
# 247/1000 epochs... 0
# 248/1000 epochs... 0
# 249/1000 epochs... 0
# 250/1000 epochs... 0
# 251/1000 epochs... 0
# 252/1000 epochs... 0
# 253/1000 epochs... 0
# 254/1000 epochs... 0
# 255/1000 epochs... 0
# 256/1000 epochs... 0
# 257/1000 epochs... 0
# 258/1000 epochs... 0
# 259/1000 epochs... 0
# 260/1000 epochs... 0
# 261/1000 epochs... 0
# 262/1000 epochs... 0
# 263/1000 epochs... 0
# 264/1000 epochs... 0
# 265/1000 epochs... 0
# 266/1000 epochs... 0
# 267/1000 epochs... 0
# 268/1000 epochs... 0
# 269/1000 epochs... 0
# 270/1000 epochs... 0
# 271/1000 epochs... 0
# 272/1000 epochs... 0
# 273/1000 epochs... 0
# 274/1000 epochs... 0
# 275/1000 epochs... 0
# 276/1000 epochs... 0
# 277/1000 epochs... 0
# 278/1000 epochs... 0
# 279/1000 epochs... 0
# 280/1000 epochs... 0
# 281/1000 epochs... 0
# 282/1000 epochs... 0
# 283/1000 epochs... 0
# 284/1000 epochs... 0
# 285/1000 epochs... 0
# 286/1000 epochs... 0
# 287/1000 epochs... 0
# 288/1000 epochs... 0
# 289/1000 epochs... 0
# 290/1000 epochs... 0
# 291/1000 epochs... 0
# 292/1000 epochs... 0
# 293/1000 epochs... 0
# 294/1000 epochs... 0
# 295/1000 epochs... 0
# 296/1000 epochs... 0
# 297/1000 epochs... 0
# 298/1000 epochs... 0
# 299/1000 epochs... 0
# 300/1000 epochs... 0
# 301/1000 epochs... 0
# 302/1000 epochs... 0
# 303/1000 epochs... 0
# 304/1000 epochs... 0
# 305/1000 epochs... 0
# 306/1000 epochs... 0
# 307/1000 epochs... 0
# 308/1000 epochs... 0
# 309/1000 epochs... 0
# 310/1000 epochs... 0
# 311/1000 epochs... 0
# 312/1000 epochs... 0
# 313/1000 epochs... 0
# 314/1000 epochs... 0
# 315/1000 epochs... 0
# 316/1000 epochs... 0
# 317/1000 epochs... 0
# 318/1000 epochs... 0
# 319/1000 epochs... 0
# 320/1000 epochs... 0
# 321/1000 epochs... 0
# 322/1000 epochs... 0
# 323/1000 epochs... 0
# 324/1000 epochs... 0
# 325/1000 epochs... 0
# 326/1000 epochs... 0
# 327/1000 epochs... 0
# 328/1000 epochs... 0
# 329/1000 epochs... 0
# 330/1000 epochs... 0
# 331/1000 epochs... 0
# 332/1000 epochs... 0
# 333/1000 epochs... 0
# 334/1000 epochs... 0
# 335/1000 epochs... 0
# 336/1000 epochs... 0
# 337/1000 epochs... 0
# 338/1000 epochs... 0
# 339/1000 epochs... 0
# 340/1000 epochs... 0
# 341/1000 epochs... 0
# 342/1000 epochs... 0
# 343/1000 epochs... 0
# 344/1000 epochs... 0
# 345/1000 epochs... 0
# 346/1000 epochs... 0
# 347/1000 epochs... 0
# 348/1000 epochs... 0
# 349/1000 epochs... 0
# 350/1000 epochs... 0
# 351/1000 epochs... 0
# 352/1000 epochs... 0
# 353/1000 epochs... 0
# 354/1000 epochs... 0
# 355/1000 epochs... 0
# 356/1000 epochs... 0
# 357/1000 epochs... 0
# 358/1000 epochs... 0
# 359/1000 epochs... 0
# 360/1000 epochs... 0
# 361/1000 epochs... 0
# 362/1000 epochs... 0
# 363/1000 epochs... 0
# 364/1000 epochs... 0
# 365/1000 epochs... 0
# 366/1000 epochs... 0
# 367/1000 epochs... 0
# 368/1000 epochs... 0
# 369/1000 epochs... 0
# 370/1000 epochs... 0
# 371/1000 epochs... 0
# 372/1000 epochs... 0
# 373/1000 epochs... 0
# 374/1000 epochs... 0
# 375/1000 epochs... 0
# 376/1000 epochs... 0
# 377/1000 epochs... 0
# 378/1000 epochs... 0
# 379/1000 epochs... 0
# 380/1000 epochs... 0
# 381/1000 epochs... 0
# 382/1000 epochs... 0
# 383/1000 epochs... 0
# 384/1000 epochs... 0
# 385/1000 epochs... 0
# 386/1000 epochs... 0
# 387/1000 epochs... 0
# 388/1000 epochs... 0
# 389/1000 epochs... 0
# 390/1000 epochs... 0
# 391/1000 epochs... 0
# 392/1000 epochs... 0
# 393/1000 epochs... 0
# 394/1000 epochs... 0
# 395/1000 epochs... 0
# 396/1000 epochs... 0
# 397/1000 epochs... 0
# 398/1000 epochs... 0
# 399/1000 epochs... 0
# 400/1000 epochs... 0
# 401/1000 epochs... 0
# 402/1000 epochs... 0
# 403/1000 epochs... 0
# 404/1000 epochs... 0
# 405/1000 epochs... 0
# 406/1000 epochs... 0
# 407/1000 epochs... 0
# 408/1000 epochs... 0
# 409/1000 epochs... 0
# 410/1000 epochs... 0
# 411/1000 epochs... 0
# 412/1000 epochs... 0
# 413/1000 epochs... 0
# 414/1000 epochs... 0
# 415/1000 epochs... 0
# 416/1000 epochs... 0
# 417/1000 epochs... 0
# 418/1000 epochs... 0
# 419/1000 epochs... 0
# 420/1000 epochs... 0
# 421/1000 epochs... 0
# 422/1000 epochs... 0
# 423/1000 epochs... 0
# 424/1000 epochs... 0
# 425/1000 epochs... 0
# 426/1000 epochs... 0
# 427/1000 epochs... 0
# 428/1000 epochs... 0
# 429/1000 epochs... 0
# 430/1000 epochs... 0
# 431/1000 epochs... 0
# 432/1000 epochs... 0
# 433/1000 epochs... 0
# 434/1000 epochs... 0
# 435/1000 epochs... 0
# 436/1000 epochs... 0
# 437/1000 epochs... 0
# 438/1000 epochs... 0
# 439/1000 epochs... 0
# 440/1000 epochs... 0
# 441/1000 epochs... 0
# 442/1000 epochs... 0
# 443/1000 epochs... 0
# 444/1000 epochs... 0
# 445/1000 epochs... 0
# 446/1000 epochs... 0
# 447/1000 epochs... 0
# 448/1000 epochs... 0
# 449/1000 epochs... 0
# 450/1000 epochs... 0
# 451/1000 epochs... 0
# 452/1000 epochs... 0
# 453/1000 epochs... 0
# 454/1000 epochs... 0
# 455/1000 epochs... 0
# 456/1000 epochs... 0
# 457/1000 epochs... 0
# 458/1000 epochs... 0
# 459/1000 epochs... 0
# 460/1000 epochs... 0
# 461/1000 epochs... 0
# 462/1000 epochs... 0
# 463/1000 epochs... 0
# 464/1000 epochs... 0
# 465/1000 epochs... 0
# 466/1000 epochs... 0
# 467/1000 epochs... 0
# 468/1000 epochs... 0
# 469/1000 epochs... 0
# 470/1000 epochs... 0
# 471/1000 epochs... 0
# 472/1000 epochs... 0
# 473/1000 epochs... 0
# 474/1000 epochs... 0
# 475/1000 epochs... 0
# 476/1000 epochs... 0
# 477/1000 epochs... 0
# 478/1000 epochs... 0
# 479/1000 epochs... 0
# 480/1000 epochs... 0
# 481/1000 epochs... 0
# 482/1000 epochs... 0
# 483/1000 epochs... 0
# 484/1000 epochs... 0
# 485/1000 epochs... 0
# 486/1000 epochs... 0
# 487/1000 epochs... 0
# 488/1000 epochs... 0
# 489/1000 epochs... 0
# 490/1000 epochs... 0
# 491/1000 epochs... 0
# 492/1000 epochs... 0
# 493/1000 epochs... 0
# 494/1000 epochs... 0
# 495/1000 epochs... 0
# 496/1000 epochs... 0
# 497/1000 epochs... 0
# 498/1000 epochs... 0
# 499/1000 epochs... 0
# 500/1000 epochs... 0
# 501/1000 epochs... 0
# 502/1000 epochs... 0
# 503/1000 epochs... 0
# 504/1000 epochs... 0
# 505/1000 epochs... 0
# 506/1000 epochs... 0
# 507/1000 epochs... 0
# 508/1000 epochs... 0
# 509/1000 epochs... 0
# 510/1000 epochs... 0
# 511/1000 epochs... 0
# 512/1000 epochs... 0
# 513/1000 epochs... 0
# 514/1000 epochs... 0
# 515/1000 epochs... 0
# 516/1000 epochs... 0
# 517/1000 epochs... 0
# 518/1000 epochs... 0
# 519/1000 epochs... 0
# 520/1000 epochs... 0
# 521/1000 epochs... 0
# 522/1000 epochs... 0
# 523/1000 epochs... 0
# 524/1000 epochs... 0
# 525/1000 epochs... 0
# 526/1000 epochs... 0
# 527/1000 epochs... 0
# 528/1000 epochs... 0
# 529/1000 epochs... 0
# 530/1000 epochs... 0
# 531/1000 epochs... 0
# 532/1000 epochs... 0
# 533/1000 epochs... 0
# 534/1000 epochs... 0
# 535/1000 epochs... 0
# 536/1000 epochs... 0
# 537/1000 epochs... 0
# 538/1000 epochs... 0
# 539/1000 epochs... 0
# 540/1000 epochs... 0
# 541/1000 epochs... 0
# 542/1000 epochs... 0
# 543/1000 epochs... 0
# 544/1000 epochs... 0
# 545/1000 epochs... 0
# 546/1000 epochs... 0
# 547/1000 epochs... 0
# 548/1000 epochs... 0
# 549/1000 epochs... 0
# 550/1000 epochs... 0
# 551/1000 epochs... 0
# 552/1000 epochs... 0
# 553/1000 epochs... 0
# 554/1000 epochs... 0
# 555/1000 epochs... 0
# 556/1000 epochs... 0
# 557/1000 epochs... 0
# 558/1000 epochs... 0
# 559/1000 epochs... 0
# 560/1000 epochs... 0
# 561/1000 epochs... 0
# 562/1000 epochs... 0
# 563/1000 epochs... 0
# 564/1000 epochs... 0
# 565/1000 epochs... 0
# 566/1000 epochs... 0
# 567/1000 epochs... 0
# 568/1000 epochs... 0
# 569/1000 epochs... 0
# 570/1000 epochs... 0
# 571/1000 epochs... 0
# 572/1000 epochs... 0
# 573/1000 epochs... 0
# 574/1000 epochs... 0
# 575/1000 epochs... 0
# 576/1000 epochs... 0
# 577/1000 epochs... 0
# 578/1000 epochs... 0
# 579/1000 epochs... 0
# 580/1000 epochs... 0
# 581/1000 epochs... 0
# 582/1000 epochs... 0
# 583/1000 epochs... 0
# 584/1000 epochs... 0
# 585/1000 epochs... 0
# 586/1000 epochs... 0
# 587/1000 epochs... 0
# 588/1000 epochs... 0
# 589/1000 epochs... 0
# 590/1000 epochs... 0
# 591/1000 epochs... 0
# 592/1000 epochs... 0
# 593/1000 epochs... 0
# 594/1000 epochs... 0
# 595/1000 epochs... 0
# 596/1000 epochs... 0
# 597/1000 epochs... 0
# 598/1000 epochs... 0
# 599/1000 epochs... 0
# 600/1000 epochs... 0
# tcmalloc: large alloc 1425391616 bytes == 0x91ede000 @  0x7fd6f0d501e7 0x7fd6ee1cd5e1 0x7fd6ee231c78 0x7fd6ee231f37 0x7fd6ee2c9f28 0x50a635 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fd6f094db97 0x5b250a
# tcmalloc: large alloc 1425391616 bytes == 0x91ede000 @  0x7fd6f0d501e7 0x7fd6ee1cd5e1 0x7fd6ee231c78 0x7fd6ee231f37 0x7fd6ee2c9f28 0x50a635 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fd6f094db97 0x5b250a
# 2020-06-01 13:26:15.557841: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x1c2f34000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# tcmalloc: large alloc 2710806528 bytes == 0x3ee6ee000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65bd9e2a4 0x7fd65bd9f107 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# Entity:
# For each left:
# Hits@1: 55.99%
# Hits@10: 74.11%
# Hits@50: 84.06%
# Hits@100: 87.33%
# For each right:
# Hits@1: 56.38%
# Hits@10: 75.73%
# Hits@50: 85.10%
# Hits@100: 88.79%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 99.24%
# Hits@50: 99.62%
# Hits@100: 99.62%
# For each right:
# Hits@1: 96.60%
# Hits@10: 99.43%
# Hits@50: 99.81%
# Hits@100: 99.81%
# 601/1000 epochs... 0.5807987
# 2020-06-01 13:27:44.920093: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x1b3e8a000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# tcmalloc: large alloc 2710806528 bytes == 0x48ef30000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65bd9e2a4 0x7fd65bd9f107 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# 602/1000 epochs... 0.5807987
# 2020-06-01 13:27:49.195159: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a658000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# 603/1000 epochs... 0.5807987
# 2020-06-01 13:27:52.087992: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a658000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# 604/1000 epochs... 0.5807987
# 2020-06-01 13:27:54.970474: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a658000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# 605/1000 epochs... 0.5807987
# tcmalloc: large alloc 3614400512 bytes == 0x13a658000 @  0x7fd6f0d32b6b 0x7fd6f0d52379 0x7fd657f4a977 0x7fd657d3808f 0x7fd657bfd42b 0x7fd657bc2e16 0x7fd657bc3ca3 0x7fd657bc3e77 0x7fd65b75ab33 0x7fd657e7c136 0x7fd657e6e785 0x7fd657f2c8b9 0x7fd657f29f88 0x7fd6ef6326df 0x7fd6f07146db 0x7fd6f0a4d88f
# 606/1000 epochs... 0.5807987
# 607/1000 epochs... 0.5807987
# 608/1000 epochs... 0.5807987
# 609/1000 epochs... 0.5807987
# 610/1000 epochs... 0.5807987
# Entity:
# For each left:
# Hits@1: 70.27%
# Hits@10: 86.78%
# Hits@50: 93.16%
# Hits@100: 95.25%
# For each right:
# Hits@1: 65.85%
# Hits@10: 84.70%
# Hits@50: 92.04%
# Hits@100: 94.19%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 98.49%
# Hits@50: 99.05%
# Hits@100: 99.24%
# For each right:
# Hits@1: 93.01%
# Hits@10: 97.73%
# Hits@50: 98.68%
# Hits@100: 99.43%
# 611/1000 epochs... 0.11583245
# 612/1000 epochs... 0.11583245
# 613/1000 epochs... 0.11583245
# 614/1000 epochs... 0.11583245
# 615/1000 epochs... 0.11583245
# 616/1000 epochs... 0.11583245
# 617/1000 epochs... 0.11583245
# 618/1000 epochs... 0.11583245
# 619/1000 epochs... 0.11583245
# 620/1000 epochs... 0.11583245
# Entity:
# For each left:
# Hits@1: 72.64%
# Hits@10: 88.56%
# Hits@50: 94.18%
# Hits@100: 96.03%
# For each right:
# Hits@1: 67.02%
# Hits@10: 85.70%
# Hits@50: 92.66%
# Hits@100: 94.70%
# Relation:
# For each left:
# Hits@1: 95.27%
# Hits@10: 98.68%
# Hits@50: 99.05%
# Hits@100: 99.05%
# For each right:
# Hits@1: 92.63%
# Hits@10: 97.35%
# Hits@50: 98.68%
# Hits@100: 99.24%
# 621/1000 epochs... 0.063111275
# 622/1000 epochs... 0.063111275
# 623/1000 epochs... 0.063111275
# 624/1000 epochs... 0.063111275
# 625/1000 epochs... 0.063111275
# 626/1000 epochs... 0.063111275
# 627/1000 epochs... 0.063111275
# 628/1000 epochs... 0.063111275
# 629/1000 epochs... 0.063111275
# 630/1000 epochs... 0.063111275
# Entity:
# For each left:
# Hits@1: 73.93%
# Hits@10: 89.50%
# Hits@50: 94.73%
# Hits@100: 96.41%
# For each right:
# Hits@1: 68.48%
# Hits@10: 86.58%
# Hits@50: 93.18%
# Hits@100: 95.20%
# Relation:
# For each left:
# Hits@1: 95.46%
# Hits@10: 98.49%
# Hits@50: 99.24%
# Hits@100: 99.43%
# For each right:
# Hits@1: 90.74%
# Hits@10: 96.03%
# Hits@50: 98.30%
# Hits@100: 99.24%
# 631/1000 epochs... 0.04669043
# 632/1000 epochs... 0.04669043
# 633/1000 epochs... 0.04669043
# 634/1000 epochs... 0.04669043
# 635/1000 epochs... 0.04669043
# 636/1000 epochs... 0.04669043
# 637/1000 epochs... 0.04669043
# 638/1000 epochs... 0.04669043
# 639/1000 epochs... 0.04669043
# 640/1000 epochs... 0.04669043
# Entity:
# For each left:
# Hits@1: 74.60%
# Hits@10: 89.72%
# Hits@50: 94.85%
# Hits@100: 96.48%
# For each right:
# Hits@1: 69.34%
# Hits@10: 86.95%
# Hits@50: 93.54%
# Hits@100: 95.42%
# Relation:
# For each left:
# Hits@1: 95.46%
# Hits@10: 98.30%
# Hits@50: 99.05%
# Hits@100: 99.43%
# For each right:
# Hits@1: 89.41%
# Hits@10: 95.84%
# Hits@50: 97.92%
# Hits@100: 98.68%
# 641/1000 epochs... 0.04214886
# 642/1000 epochs... 0.04214886
# 643/1000 epochs... 0.04214886
# 644/1000 epochs... 0.04214886
# 645/1000 epochs... 0.04214886
# 646/1000 epochs... 0.04214886
# 647/1000 epochs... 0.04214886
# 648/1000 epochs... 0.04214886
# 649/1000 epochs... 0.04214886
# 650/1000 epochs... 0.04214886
# Entity:
# For each left:
# Hits@1: 75.19%
# Hits@10: 89.77%
# Hits@50: 94.93%
# Hits@100: 96.46%
# For each right:
# Hits@1: 70.02%
# Hits@10: 87.33%
# Hits@50: 93.80%
# Hits@100: 95.54%
# Relation:
# For each left:
# Hits@1: 95.09%
# Hits@10: 98.11%
# Hits@50: 98.87%
# Hits@100: 99.43%
# For each right:
# Hits@1: 89.22%
# Hits@10: 94.52%
# Hits@50: 97.92%
# Hits@100: 98.68%
# 651/1000 epochs... 0.039498862
# 652/1000 epochs... 0.039498862
# 653/1000 epochs... 0.039498862
# 654/1000 epochs... 0.039498862
# 655/1000 epochs... 0.039498862
# 656/1000 epochs... 0.039498862
# 657/1000 epochs... 0.039498862
# 658/1000 epochs... 0.039498862
# 659/1000 epochs... 0.039498862
# 660/1000 epochs... 0.039498862
# Entity:
# For each left:
# Hits@1: 75.34%
# Hits@10: 89.93%
# Hits@50: 94.85%
# Hits@100: 96.31%
# For each right:
# Hits@1: 70.51%
# Hits@10: 87.49%
# Hits@50: 93.92%
# Hits@100: 95.67%
# Relation:
# For each left:
# Hits@1: 94.90%
# Hits@10: 97.92%
# Hits@50: 98.68%
# Hits@100: 99.24%
# For each right:
# Hits@1: 88.85%
# Hits@10: 94.14%
# Hits@50: 97.35%
# Hits@100: 98.49%
# 661/1000 epochs... 0.037799105
# 662/1000 epochs... 0.037799105
# 663/1000 epochs... 0.037799105
# 664/1000 epochs... 0.037799105
# 665/1000 epochs... 0.037799105
# 666/1000 epochs... 0.037799105
# 667/1000 epochs... 0.037799105
# 668/1000 epochs... 0.037799105
# 669/1000 epochs... 0.037799105
# 670/1000 epochs... 0.037799105
# Entity:
# For each left:
# Hits@1: 75.56%
# Hits@10: 89.98%
# Hits@50: 94.81%
# Hits@100: 96.23%
# For each right:
# Hits@1: 70.94%
# Hits@10: 87.53%
# Hits@50: 94.05%
# Hits@100: 95.64%
# Relation:
# For each left:
# Hits@1: 94.52%
# Hits@10: 97.54%
# Hits@50: 98.49%
# Hits@100: 99.05%
# For each right:
# Hits@1: 88.66%
# Hits@10: 93.57%
# Hits@50: 97.35%
# Hits@100: 98.68%
# 671/1000 epochs... 0.036562964
# 672/1000 epochs... 0.036562964
# 673/1000 epochs... 0.036562964
# 674/1000 epochs... 0.036562964
# 675/1000 epochs... 0.036562964
# 676/1000 epochs... 0.036562964
# 677/1000 epochs... 0.036562964
# 678/1000 epochs... 0.036562964
# 679/1000 epochs... 0.036562964
# 680/1000 epochs... 0.036562964
# Entity:
# For each left:
# Hits@1: 75.71%
# Hits@10: 90.04%
# Hits@50: 94.80%
# Hits@100: 96.19%
# For each right:
# Hits@1: 71.11%
# Hits@10: 87.73%
# Hits@50: 94.01%
# Hits@100: 95.65%
# Relation:
# For each left:
# Hits@1: 93.95%
# Hits@10: 97.16%
# Hits@50: 98.30%
# Hits@100: 98.87%
# For each right:
# Hits@1: 88.47%
# Hits@10: 93.38%
# Hits@50: 97.16%
# Hits@100: 98.49%
# 681/1000 epochs... 0.035554595
# 682/1000 epochs... 0.035554595
# 683/1000 epochs... 0.035554595
# 684/1000 epochs... 0.035554595
# 685/1000 epochs... 0.035554595
# 686/1000 epochs... 0.035554595
# 687/1000 epochs... 0.035554595
# 688/1000 epochs... 0.035554595
# 689/1000 epochs... 0.035554595
# 690/1000 epochs... 0.035554595
# Entity:
# For each left:
# Hits@1: 75.84%
# Hits@10: 90.08%
# Hits@50: 94.73%
# Hits@100: 96.16%
# For each right:
# Hits@1: 71.36%
# Hits@10: 87.93%
# Hits@50: 94.01%
# Hits@100: 95.73%
# Relation:
# For each left:
# Hits@1: 93.76%
# Hits@10: 96.98%
# Hits@50: 98.11%
# Hits@100: 98.87%
# For each right:
# Hits@1: 87.33%
# Hits@10: 93.57%
# Hits@50: 96.79%
# Hits@100: 98.49%
# 691/1000 epochs... 0.034680806
# 692/1000 epochs... 0.034680806
# 693/1000 epochs... 0.034680806
# 694/1000 epochs... 0.034680806
# 695/1000 epochs... 0.034680806
# 696/1000 epochs... 0.034680806
# 697/1000 epochs... 0.034680806
# 698/1000 epochs... 0.034680806
# 699/1000 epochs... 0.034680806
# 700/1000 epochs... 0.034680806
# Entity:
# For each left:
# Hits@1: 75.99%
# Hits@10: 90.13%
# Hits@50: 94.71%
# Hits@100: 96.20%
# For each right:
# Hits@1: 71.52%
# Hits@10: 88.05%
# Hits@50: 94.10%
# Hits@100: 95.77%
# Relation:
# For each left:
# Hits@1: 93.76%
# Hits@10: 96.60%
# Hits@50: 97.92%
# Hits@100: 98.87%
# For each right:
# Hits@1: 87.33%
# Hits@10: 92.63%
# Hits@50: 96.60%
# Hits@100: 98.30%
# 701/1000 epochs... 0.033897374
# 702/1000 epochs... 0.033897374
# 703/1000 epochs... 0.033897374
# 704/1000 epochs... 0.033897374
# 705/1000 epochs... 0.033897374
# 706/1000 epochs... 0.033897374
# 707/1000 epochs... 0.033897374
# 708/1000 epochs... 0.033897374
# 709/1000 epochs... 0.033897374
# 710/1000 epochs... 0.033897374
# Entity:
# For each left:
# Hits@1: 76.06%
# Hits@10: 90.10%
# Hits@50: 94.70%
# Hits@100: 96.15%
# For each right:
# Hits@1: 71.69%
# Hits@10: 88.18%
# Hits@50: 94.16%
# Hits@100: 95.81%
# Relation:
# For each left:
# Hits@1: 93.38%
# Hits@10: 96.60%
# Hits@50: 97.54%
# Hits@100: 98.87%
# For each right:
# Hits@1: 86.20%
# Hits@10: 91.87%
# Hits@50: 96.60%
# Hits@100: 98.30%
# 711/1000 epochs... 0.033184517
# 712/1000 epochs... 0.033184517
# 713/1000 epochs... 0.033184517
# 714/1000 epochs... 0.033184517
# 715/1000 epochs... 0.033184517
# 716/1000 epochs... 0.033184517
# 717/1000 epochs... 0.033184517
# 718/1000 epochs... 0.033184517
# 719/1000 epochs... 0.033184517
# 720/1000 epochs... 0.033184517
# Entity:
# For each left:
# Hits@1: 76.24%
# Hits@10: 90.14%
# Hits@50: 94.70%
# Hits@100: 96.14%
# For each right:
# Hits@1: 71.98%
# Hits@10: 88.24%
# Hits@50: 94.26%
# Hits@100: 95.78%
# Relation:
# For each left:
# Hits@1: 92.82%
# Hits@10: 96.41%
# Hits@50: 97.54%
# Hits@100: 98.68%
# For each right:
# Hits@1: 86.20%
# Hits@10: 91.49%
# Hits@50: 96.60%
# Hits@100: 97.73%
# 721/1000 epochs... 0.032526016
# 722/1000 epochs... 0.032526016
# 723/1000 epochs... 0.032526016
# 724/1000 epochs... 0.032526016
# 725/1000 epochs... 0.032526016
# 726/1000 epochs... 0.032526016
# 727/1000 epochs... 0.032526016
# 728/1000 epochs... 0.032526016
# 729/1000 epochs... 0.032526016
# 730/1000 epochs... 0.032526016
# Entity:
# For each left:
# Hits@1: 76.45%
# Hits@10: 90.14%
# Hits@50: 94.70%
# Hits@100: 96.15%
# For each right:
# Hits@1: 72.16%
# Hits@10: 88.37%
# Hits@50: 94.27%
# Hits@100: 95.82%
# Relation:
# For each left:
# Hits@1: 92.44%
# Hits@10: 95.84%
# Hits@50: 96.98%
# Hits@100: 97.92%
# For each right:
# Hits@1: 85.82%
# Hits@10: 90.36%
# Hits@50: 95.65%
# Hits@100: 97.73%
# 731/1000 epochs... 0.03191166
# 732/1000 epochs... 0.03191166
# 733/1000 epochs... 0.03191166
# 734/1000 epochs... 0.03191166
# 735/1000 epochs... 0.03191166
# 736/1000 epochs... 0.03191166
# 737/1000 epochs... 0.03191166
# 738/1000 epochs... 0.03191166
# 739/1000 epochs... 0.03191166
# 740/1000 epochs... 0.03191166
# Entity:
# For each left:
# Hits@1: 76.57%
# Hits@10: 90.19%
# Hits@50: 94.69%
# Hits@100: 96.15%
# For each right:
# Hits@1: 72.35%
# Hits@10: 88.42%
# Hits@50: 94.30%
# Hits@100: 95.88%
# Relation:
# For each left:
# Hits@1: 92.25%
# Hits@10: 95.46%
# Hits@50: 96.79%
# Hits@100: 97.92%
# For each right:
# Hits@1: 85.07%
# Hits@10: 89.60%
# Hits@50: 95.27%
# Hits@100: 97.54%
# 741/1000 epochs... 0.031335086
# 742/1000 epochs... 0.031335086
# 743/1000 epochs... 0.031335086
# 744/1000 epochs... 0.031335086
# 745/1000 epochs... 0.031335086
# 746/1000 epochs... 0.031335086
# 747/1000 epochs... 0.031335086
# 748/1000 epochs... 0.031335086
# 749/1000 epochs... 0.031335086
# 750/1000 epochs... 0.031335086
# Entity:
# For each left:
# Hits@1: 76.55%
# Hits@10: 90.23%
# Hits@50: 94.68%
# Hits@100: 96.15%
# For each right:
# Hits@1: 72.51%
# Hits@10: 88.56%
# Hits@50: 94.32%
# Hits@100: 95.87%
# Relation:
# For each left:
# Hits@1: 92.06%
# Hits@10: 95.09%
# Hits@50: 96.60%
# Hits@100: 97.54%
# For each right:
# Hits@1: 84.31%
# Hits@10: 89.04%
# Hits@50: 94.71%
# Hits@100: 97.35%
# 751/1000 epochs... 0.030791227
# 752/1000 epochs... 0.030791227
# 753/1000 epochs... 0.030791227
# 754/1000 epochs... 0.030791227
# 755/1000 epochs... 0.030791227
# 756/1000 epochs... 0.030791227
# 757/1000 epochs... 0.030791227
# 758/1000 epochs... 0.030791227
# 759/1000 epochs... 0.030791227
# 760/1000 epochs... 0.030791227
# Entity:
# For each left:
# Hits@1: 76.60%
# Hits@10: 90.24%
# Hits@50: 94.65%
# Hits@100: 96.11%
# For each right:
# Hits@1: 72.67%
# Hits@10: 88.57%
# Hits@50: 94.32%
# Hits@100: 95.83%
# Relation:
# For each left:
# Hits@1: 90.93%
# Hits@10: 94.52%
# Hits@50: 96.22%
# Hits@100: 97.54%
# For each right:
# Hits@1: 83.93%
# Hits@10: 88.09%
# Hits@50: 94.52%
# Hits@100: 97.16%
# 761/1000 epochs... 0.030276844
# 762/1000 epochs... 0.030276844
# 763/1000 epochs... 0.030276844
# 764/1000 epochs... 0.030276844
# 765/1000 epochs... 0.030276844
# 766/1000 epochs... 0.030276844
# 767/1000 epochs... 0.030276844
# 768/1000 epochs... 0.030276844
# 769/1000 epochs... 0.030276844
# 770/1000 epochs... 0.030276844
# Entity:
# For each left:
# Hits@1: 76.56%
# Hits@10: 90.28%
# Hits@50: 94.64%
# Hits@100: 96.09%
# For each right:
# Hits@1: 72.80%
# Hits@10: 88.68%
# Hits@50: 94.30%
# Hits@100: 95.86%
# Relation:
# For each left:
# Hits@1: 90.17%
# Hits@10: 94.14%
# Hits@50: 95.84%
# Hits@100: 97.16%
# For each right:
# Hits@1: 83.18%
# Hits@10: 86.96%
# Hits@50: 93.01%
# Hits@100: 96.79%
# 771/1000 epochs... 0.02978814
# 772/1000 epochs... 0.02978814
# 773/1000 epochs... 0.02978814
# 774/1000 epochs... 0.02978814
# 775/1000 epochs... 0.02978814
# 776/1000 epochs... 0.02978814
# 777/1000 epochs... 0.02978814
# 778/1000 epochs... 0.02978814
# 779/1000 epochs... 0.02978814
# 780/1000 epochs... 0.02978814
# Entity:
# For each left:
# Hits@1: 76.56%
# Hits@10: 90.31%
# Hits@50: 94.65%
# Hits@100: 96.05%
# For each right:
# Hits@1: 72.90%
# Hits@10: 88.66%
# Hits@50: 94.28%
# Hits@100: 95.84%
# Relation:
# For each left:
# Hits@1: 89.60%
# Hits@10: 93.76%
# Hits@50: 95.27%
# Hits@100: 97.16%
# For each right:
# Hits@1: 82.42%
# Hits@10: 86.39%
# Hits@50: 92.06%
# Hits@100: 95.84%
# 781/1000 epochs... 0.029323049
# 782/1000 epochs... 0.029323049
# 783/1000 epochs... 0.029323049
# 784/1000 epochs... 0.029323049
# 785/1000 epochs... 0.029323049
# 786/1000 epochs... 0.029323049
# 787/1000 epochs... 0.029323049
# 788/1000 epochs... 0.029323049
# 789/1000 epochs... 0.029323049
# 790/1000 epochs... 0.029323049
# Entity:
# For each left:
# Hits@1: 76.63%
# Hits@10: 90.34%
# Hits@50: 94.61%
# Hits@100: 96.05%
# For each right:
# Hits@1: 72.94%
# Hits@10: 88.70%
# Hits@50: 94.23%
# Hits@100: 95.79%
# Relation:
# For each left:
# Hits@1: 88.85%
# Hits@10: 93.01%
# Hits@50: 94.71%
# Hits@100: 97.16%
# For each right:
# Hits@1: 80.53%
# Hits@10: 86.20%
# Hits@50: 90.93%
# Hits@100: 95.46%
# 791/1000 epochs... 0.028879516
# 792/1000 epochs... 0.028879516
# 793/1000 epochs... 0.028879516
# 794/1000 epochs... 0.028879516
# 795/1000 epochs... 0.028879516
# 796/1000 epochs... 0.028879516
# 797/1000 epochs... 0.028879516
# 798/1000 epochs... 0.028879516
# 799/1000 epochs... 0.028879516
# Model saved in path: ./saved_model/ja_en/model_s3.ckpt
# 800/1000 epochs... 0.028879516
# Entity:
# For each left:
# Hits@1: 76.64%
# Hits@10: 90.39%
# Hits@50: 94.61%
# Hits@100: 96.03%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.74%
# Hits@50: 94.24%
# Hits@100: 95.76%
# Relation:
# For each left:
# Hits@1: 88.85%
# Hits@10: 92.44%
# Hits@50: 94.14%
# Hits@100: 96.79%
# For each right:
# Hits@1: 79.96%
# Hits@10: 85.07%
# Hits@50: 90.55%
# Hits@100: 95.27%
# 801/1000 epochs... 0.02845647
# 802/1000 epochs... 0.02845647
# 803/1000 epochs... 0.02845647
# 804/1000 epochs... 0.02845647
# 805/1000 epochs... 0.02845647
# 806/1000 epochs... 0.02845647
# 807/1000 epochs... 0.02845647
# 808/1000 epochs... 0.02845647
# 809/1000 epochs... 0.02845647
# 810/1000 epochs... 0.02845647
# Entity:
# For each left:
# Hits@1: 76.63%
# Hits@10: 90.42%
# Hits@50: 94.59%
# Hits@100: 95.99%
# For each right:
# Hits@1: 73.07%
# Hits@10: 88.75%
# Hits@50: 94.22%
# Hits@100: 95.76%
# Relation:
# For each left:
# Hits@1: 88.09%
# Hits@10: 92.44%
# Hits@50: 93.57%
# Hits@100: 96.03%
# For each right:
# Hits@1: 79.40%
# Hits@10: 84.50%
# Hits@50: 90.17%
# Hits@100: 94.33%
# 811/1000 epochs... 0.028052848
# 812/1000 epochs... 0.028052848
# 813/1000 epochs... 0.028052848
# 814/1000 epochs... 0.028052848
# 815/1000 epochs... 0.028052848
# 816/1000 epochs... 0.028052848
# 817/1000 epochs... 0.028052848
# 818/1000 epochs... 0.028052848
# 819/1000 epochs... 0.028052848
# 820/1000 epochs... 0.028052848
# Entity:
# For each left:
# Hits@1: 76.70%
# Hits@10: 90.47%
# Hits@50: 94.61%
# Hits@100: 95.97%
# For each right:
# Hits@1: 73.07%
# Hits@10: 88.74%
# Hits@50: 94.21%
# Hits@100: 95.73%
# Relation:
# For each left:
# Hits@1: 87.71%
# Hits@10: 92.25%
# Hits@50: 93.57%
# Hits@100: 94.90%
# For each right:
# Hits@1: 77.88%
# Hits@10: 83.74%
# Hits@50: 89.60%
# Hits@100: 93.76%
# 821/1000 epochs... 0.0276673
# 822/1000 epochs... 0.0276673
# 823/1000 epochs... 0.0276673
# 824/1000 epochs... 0.0276673
# 825/1000 epochs... 0.0276673
# 826/1000 epochs... 0.0276673
# 827/1000 epochs... 0.0276673
# 828/1000 epochs... 0.0276673
# 829/1000 epochs... 0.0276673
# 830/1000 epochs... 0.0276673
# Entity:
# For each left:
# Hits@1: 76.68%
# Hits@10: 90.45%
# Hits@50: 94.58%
# Hits@100: 95.93%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.71%
# Hits@50: 94.23%
# Hits@100: 95.70%
# Relation:
# For each left:
# Hits@1: 86.39%
# Hits@10: 91.68%
# Hits@50: 93.57%
# Hits@100: 94.71%
# For each right:
# Hits@1: 76.37%
# Hits@10: 82.80%
# Hits@50: 88.66%
# Hits@100: 93.38%
# 831/1000 epochs... 0.02729826
# 832/1000 epochs... 0.02729826
# 833/1000 epochs... 0.02729826
# 834/1000 epochs... 0.02729826
# 835/1000 epochs... 0.02729826
# 836/1000 epochs... 0.02729826
# 837/1000 epochs... 0.02729826
# 838/1000 epochs... 0.02729826
# 839/1000 epochs... 0.02729826
# 840/1000 epochs... 0.02729826
# Entity:
# For each left:
# Hits@1: 76.69%
# Hits@10: 90.38%
# Hits@50: 94.59%
# Hits@100: 95.92%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.71%
# Hits@50: 94.22%
# Hits@100: 95.70%
# Relation:
# For each left:
# Hits@1: 85.44%
# Hits@10: 90.36%
# Hits@50: 93.57%
# Hits@100: 94.52%
# For each right:
# Hits@1: 75.05%
# Hits@10: 81.85%
# Hits@50: 87.52%
# Hits@100: 92.44%
# 841/1000 epochs... 0.02694512
# 842/1000 epochs... 0.02694512
# 843/1000 epochs... 0.02694512
# 844/1000 epochs... 0.02694512
# 845/1000 epochs... 0.02694512
# 846/1000 epochs... 0.02694512
# 847/1000 epochs... 0.02694512
# 848/1000 epochs... 0.02694512
# 849/1000 epochs... 0.02694512
# 850/1000 epochs... 0.02694512
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.35%
# Hits@50: 94.61%
# Hits@100: 95.91%
# For each right:
# Hits@1: 73.11%
# Hits@10: 88.72%
# Hits@50: 94.18%
# Hits@100: 95.62%
# Relation:
# For each left:
# Hits@1: 84.88%
# Hits@10: 89.79%
# Hits@50: 93.19%
# Hits@100: 94.33%
# For each right:
# Hits@1: 73.53%
# Hits@10: 80.91%
# Hits@50: 86.01%
# Hits@100: 91.87%
# 851/1000 epochs... 0.026607191
# 852/1000 epochs... 0.026607191
# 853/1000 epochs... 0.026607191
# 854/1000 epochs... 0.026607191
# 855/1000 epochs... 0.026607191
# 856/1000 epochs... 0.026607191
# 857/1000 epochs... 0.026607191
# 858/1000 epochs... 0.026607191
# 859/1000 epochs... 0.026607191
# 860/1000 epochs... 0.026607191
# Entity:
# For each left:
# Hits@1: 76.76%
# Hits@10: 90.38%
# Hits@50: 94.58%
# Hits@100: 95.87%
# For each right:
# Hits@1: 73.15%
# Hits@10: 88.78%
# Hits@50: 94.16%
# Hits@100: 95.61%
# Relation:
# For each left:
# Hits@1: 84.31%
# Hits@10: 89.41%
# Hits@50: 92.44%
# Hits@100: 94.14%
# For each right:
# Hits@1: 73.16%
# Hits@10: 79.40%
# Hits@50: 85.44%
# Hits@100: 91.49%
# 861/1000 epochs... 0.026283126
# 862/1000 epochs... 0.026283126
# 863/1000 epochs... 0.026283126
# 864/1000 epochs... 0.026283126
# 865/1000 epochs... 0.026283126
# 866/1000 epochs... 0.026283126
# 867/1000 epochs... 0.026283126
# 868/1000 epochs... 0.026283126
# 869/1000 epochs... 0.026283126
# 870/1000 epochs... 0.026283126
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.40%
# Hits@50: 94.54%
# Hits@100: 95.81%
# For each right:
# Hits@1: 73.20%
# Hits@10: 88.79%
# Hits@50: 94.13%
# Hits@100: 95.57%
# Relation:
# For each left:
# Hits@1: 83.55%
# Hits@10: 88.66%
# Hits@50: 92.06%
# Hits@100: 93.95%
# For each right:
# Hits@1: 72.40%
# Hits@10: 78.26%
# Hits@50: 84.50%
# Hits@100: 90.74%
# 871/1000 epochs... 0.025971904
# 872/1000 epochs... 0.025971904
# 873/1000 epochs... 0.025971904
# 874/1000 epochs... 0.025971904
# 875/1000 epochs... 0.025971904
# 876/1000 epochs... 0.025971904
# 877/1000 epochs... 0.025971904
# 878/1000 epochs... 0.025971904
# 879/1000 epochs... 0.025971904
# 880/1000 epochs... 0.025971904
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.41%
# Hits@50: 94.59%
# Hits@100: 95.78%
# For each right:
# Hits@1: 73.15%
# Hits@10: 88.81%
# Hits@50: 94.12%
# Hits@100: 95.56%
# Relation:
# For each left:
# Hits@1: 83.18%
# Hits@10: 88.09%
# Hits@50: 91.68%
# Hits@100: 93.57%
# For each right:
# Hits@1: 71.27%
# Hits@10: 77.69%
# Hits@50: 83.18%
# Hits@100: 89.98%
# 881/1000 epochs... 0.025672674
# 882/1000 epochs... 0.025672674
# 883/1000 epochs... 0.025672674
# 884/1000 epochs... 0.025672674
# 885/1000 epochs... 0.025672674
# 886/1000 epochs... 0.025672674
# 887/1000 epochs... 0.025672674
# 888/1000 epochs... 0.025672674
# 889/1000 epochs... 0.025672674
# 890/1000 epochs... 0.025672674
# Entity:
# For each left:
# Hits@1: 76.72%
# Hits@10: 90.40%
# Hits@50: 94.58%
# Hits@100: 95.77%
# For each right:
# Hits@1: 73.11%
# Hits@10: 88.82%
# Hits@50: 94.07%
# Hits@100: 95.54%
# Relation:
# For each left:
# Hits@1: 83.18%
# Hits@10: 87.90%
# Hits@50: 90.93%
# Hits@100: 93.19%
# For each right:
# Hits@1: 70.13%
# Hits@10: 77.13%
# Hits@50: 82.42%
# Hits@100: 89.41%
# 891/1000 epochs... 0.025385465
# 892/1000 epochs... 0.025385465
# 893/1000 epochs... 0.025385465
# 894/1000 epochs... 0.025385465
# 895/1000 epochs... 0.025385465
# 896/1000 epochs... 0.025385465
# 897/1000 epochs... 0.025385465
# 898/1000 epochs... 0.025385465
# 899/1000 epochs... 0.025385465
# 900/1000 epochs... 0.025385465
# Entity:
# For each left:
# Hits@1: 76.83%
# Hits@10: 90.39%
# Hits@50: 94.55%
# Hits@100: 95.75%
# For each right:
# Hits@1: 73.12%
# Hits@10: 88.78%
# Hits@50: 94.04%
# Hits@100: 95.55%
# Relation:
# For each left:
# Hits@1: 82.42%
# Hits@10: 87.90%
# Hits@50: 90.55%
# Hits@100: 93.19%
# For each right:
# Hits@1: 69.38%
# Hits@10: 76.37%
# Hits@50: 81.47%
# Hits@100: 88.47%
# 901/1000 epochs... 0.02511039
# 902/1000 epochs... 0.02511039
# 903/1000 epochs... 0.02511039
# 904/1000 epochs... 0.02511039
# 905/1000 epochs... 0.02511039
# 906/1000 epochs... 0.02511039
# 907/1000 epochs... 0.02511039
# 908/1000 epochs... 0.02511039
# 909/1000 epochs... 0.02511039
# 910/1000 epochs... 0.02511039
# Entity:
# For each left:
# Hits@1: 76.87%
# Hits@10: 90.32%
# Hits@50: 94.52%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.09%
# Hits@10: 88.77%
# Hits@50: 94.01%
# Hits@100: 95.52%
# Relation:
# For each left:
# Hits@1: 82.04%
# Hits@10: 86.96%
# Hits@50: 90.36%
# Hits@100: 93.01%
# For each right:
# Hits@1: 69.00%
# Hits@10: 75.61%
# Hits@50: 81.29%
# Hits@100: 87.33%
# 911/1000 epochs... 0.024846504
# 912/1000 epochs... 0.024846504
# 913/1000 epochs... 0.024846504
# 914/1000 epochs... 0.024846504
# 915/1000 epochs... 0.024846504
# 916/1000 epochs... 0.024846504
# 917/1000 epochs... 0.024846504
# 918/1000 epochs... 0.024846504
# 919/1000 epochs... 0.024846504
# 920/1000 epochs... 0.024846504
# Entity:
# For each left:
# Hits@1: 76.85%
# Hits@10: 90.29%
# Hits@50: 94.53%
# Hits@100: 95.69%
# For each right:
# Hits@1: 73.17%
# Hits@10: 88.72%
# Hits@50: 93.97%
# Hits@100: 95.49%
# Relation:
# For each left:
# Hits@1: 81.10%
# Hits@10: 86.39%
# Hits@50: 89.79%
# Hits@100: 92.82%
# For each right:
# Hits@1: 68.24%
# Hits@10: 75.05%
# Hits@50: 80.91%
# Hits@100: 86.01%
# 921/1000 epochs... 0.024593962
# 922/1000 epochs... 0.024593962
# 923/1000 epochs... 0.024593962
# 924/1000 epochs... 0.024593962
# 925/1000 epochs... 0.024593962
# 926/1000 epochs... 0.024593962
# 927/1000 epochs... 0.024593962
# 928/1000 epochs... 0.024593962
# 929/1000 epochs... 0.024593962
# 930/1000 epochs... 0.024593962
# Entity:
# For each left:
# Hits@1: 76.93%
# Hits@10: 90.30%
# Hits@50: 94.50%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.24%
# Hits@10: 88.77%
# Hits@50: 93.94%
# Hits@100: 95.47%
# Relation:
# For each left:
# Hits@1: 80.53%
# Hits@10: 85.44%
# Hits@50: 89.41%
# Hits@100: 92.63%
# For each right:
# Hits@1: 67.49%
# Hits@10: 74.29%
# Hits@50: 80.53%
# Hits@100: 84.88%
# 931/1000 epochs... 0.024350898
# 932/1000 epochs... 0.024350898
# 933/1000 epochs... 0.024350898
# 934/1000 epochs... 0.024350898
# 935/1000 epochs... 0.024350898
# 936/1000 epochs... 0.024350898
# 937/1000 epochs... 0.024350898
# 938/1000 epochs... 0.024350898
# 939/1000 epochs... 0.024350898
# 940/1000 epochs... 0.024350898
# Entity:
# For each left:
# Hits@1: 76.90%
# Hits@10: 90.26%
# Hits@50: 94.49%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.27%
# Hits@10: 88.74%
# Hits@50: 93.92%
# Hits@100: 95.44%
# Relation:
# For each left:
# Hits@1: 79.96%
# Hits@10: 85.07%
# Hits@50: 89.41%
# Hits@100: 92.25%
# For each right:
# Hits@1: 66.73%
# Hits@10: 73.16%
# Hits@50: 79.96%
# Hits@100: 84.12%
# 941/1000 epochs... 0.024118384
# 942/1000 epochs... 0.024118384
# 943/1000 epochs... 0.024118384
# 944/1000 epochs... 0.024118384
# 945/1000 epochs... 0.024118384
# 946/1000 epochs... 0.024118384
# 947/1000 epochs... 0.024118384
# 948/1000 epochs... 0.024118384
# 949/1000 epochs... 0.024118384
# 950/1000 epochs... 0.024118384
# Entity:
# For each left:
# Hits@1: 76.85%
# Hits@10: 90.22%
# Hits@50: 94.50%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.25%
# Hits@10: 88.75%
# Hits@50: 93.90%
# Hits@100: 95.43%
# Relation:
# For each left:
# Hits@1: 78.83%
# Hits@10: 84.69%
# Hits@50: 88.47%
# Hits@100: 91.68%
# For each right:
# Hits@1: 65.60%
# Hits@10: 72.59%
# Hits@50: 79.40%
# Hits@100: 83.18%
# 951/1000 epochs... 0.023895346
# 952/1000 epochs... 0.023895346
# 953/1000 epochs... 0.023895346
# 954/1000 epochs... 0.023895346
# 955/1000 epochs... 0.023895346
# 956/1000 epochs... 0.023895346
# 957/1000 epochs... 0.023895346
# 958/1000 epochs... 0.023895346
# 959/1000 epochs... 0.023895346
# 960/1000 epochs... 0.023895346
# Entity:
# For each left:
# Hits@1: 76.84%
# Hits@10: 90.22%
# Hits@50: 94.49%
# Hits@100: 95.63%
# For each right:
# Hits@1: 73.29%
# Hits@10: 88.69%
# Hits@50: 93.90%
# Hits@100: 95.41%
# Relation:
# For each left:
# Hits@1: 78.45%
# Hits@10: 83.74%
# Hits@50: 87.71%
# Hits@100: 91.30%
# For each right:
# Hits@1: 65.60%
# Hits@10: 71.64%
# Hits@50: 79.40%
# Hits@100: 83.36%
# 961/1000 epochs... 0.02368168
# 962/1000 epochs... 0.02368168
# 963/1000 epochs... 0.02368168
# 964/1000 epochs... 0.02368168
# 965/1000 epochs... 0.02368168
# 966/1000 epochs... 0.02368168
# 967/1000 epochs... 0.02368168
# 968/1000 epochs... 0.02368168
# 969/1000 epochs... 0.02368168
# 970/1000 epochs... 0.02368168
# Entity:
# For each left:
# Hits@1: 76.86%
# Hits@10: 90.18%
# Hits@50: 94.49%
# Hits@100: 95.62%
# For each right:
# Hits@1: 73.26%
# Hits@10: 88.60%
# Hits@50: 93.88%
# Hits@100: 95.40%
# Relation:
# For each left:
# Hits@1: 78.45%
# Hits@10: 82.99%
# Hits@50: 87.33%
# Hits@100: 91.12%
# For each right:
# Hits@1: 65.03%
# Hits@10: 71.46%
# Hits@50: 79.21%
# Hits@100: 82.42%
# 971/1000 epochs... 0.023476541
# 972/1000 epochs... 0.023476541
# 973/1000 epochs... 0.023476541
# 974/1000 epochs... 0.023476541
# 975/1000 epochs... 0.023476541
# 976/1000 epochs... 0.023476541
# 977/1000 epochs... 0.023476541
# 978/1000 epochs... 0.023476541
# 979/1000 epochs... 0.023476541
# 980/1000 epochs... 0.023476541

# %%
# last 200 epochs
# !python main.py
# Out:
# WARNING:tensorflow:From main.py:18: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loading a file...data/ja_en/ent_ids_1
# loading a file...data/ja_en/ent_ids_2
# loading a file...data/ja_en/shuffled_ref_ent_ids
# loading a file...data/ja_en/ref_r_ids
# loading a file...data/ja_en/triples_1
# loading a file...data/ja_en/triples_2
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:263: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# adding the primal input layer...
# 39594 rows, 300 columns.
# getting a sparse tensor...
# tcmalloc: large alloc 12541485056 bytes == 0x1a1a8000 @  0x7f1fe5882001 0x7f1fe2cfd765 0x7f1fe2d61bb0 0x7f1fe2d63a4f 0x7f1fe2dfa048 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1fe547db97 0x5b250a
# calculate relation representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Init.py:17: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# first interaction...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:107: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# adding sparse attention layer...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:114: The name tf.sparse_softmax is deprecated. Please use tf.sparse.softmax instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:115: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# second interaction...
# adding sparse attention layer...
# getting loss...
# gcn layers...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:84: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# adding a diag layer...
# adding a diag layer...
# calculate joint entity representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:297: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# getting loss...
# getting loss...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:326: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# initializing...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:330: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:331: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-06-07 08:59:24.391738: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-07 08:59:24.437015: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-06-07 08:59:24.437102: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d8702d1d7997): /proc/driver/nvidia/version does not exist
# 2020-06-07 08:59:24.450634: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-06-07 08:59:24.452805: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x243ca00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-07 08:59:24.452847: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# running...
# Model restore from path: None
# 1/1000 epochs... 0
# 2/1000 epochs... 0
# 3/1000 epochs... 0
# 4/1000 epochs... 0
# 5/1000 epochs... 0
# 6/1000 epochs... 0
# 7/1000 epochs... 0
# 8/1000 epochs... 0
# 9/1000 epochs... 0
# 10/1000 epochs... 0
# 11/1000 epochs... 0
# 12/1000 epochs... 0
# 13/1000 epochs... 0
# 14/1000 epochs... 0
# 15/1000 epochs... 0
# 16/1000 epochs... 0
# 17/1000 epochs... 0
# 18/1000 epochs... 0
# 19/1000 epochs... 0
# 20/1000 epochs... 0
# 21/1000 epochs... 0
# 22/1000 epochs... 0
# 23/1000 epochs... 0
# 24/1000 epochs... 0
# 25/1000 epochs... 0
# 26/1000 epochs... 0
# 27/1000 epochs... 0
# 28/1000 epochs... 0
# 29/1000 epochs... 0
# 30/1000 epochs... 0
# 31/1000 epochs... 0
# 32/1000 epochs... 0
# 33/1000 epochs... 0
# 34/1000 epochs... 0
# 35/1000 epochs... 0
# 36/1000 epochs... 0
# 37/1000 epochs... 0
# 38/1000 epochs... 0
# 39/1000 epochs... 0
# 40/1000 epochs... 0
# 41/1000 epochs... 0
# 42/1000 epochs... 0
# 43/1000 epochs... 0
# 44/1000 epochs... 0
# 45/1000 epochs... 0
# 46/1000 epochs... 0
# 47/1000 epochs... 0
# 48/1000 epochs... 0
# 49/1000 epochs... 0
# 50/1000 epochs... 0
# 51/1000 epochs... 0
# 52/1000 epochs... 0
# 53/1000 epochs... 0
# 54/1000 epochs... 0
# 55/1000 epochs... 0
# 56/1000 epochs... 0
# 57/1000 epochs... 0
# 58/1000 epochs... 0
# 59/1000 epochs... 0
# 60/1000 epochs... 0
# 61/1000 epochs... 0
# 62/1000 epochs... 0
# 63/1000 epochs... 0
# 64/1000 epochs... 0
# 65/1000 epochs... 0
# 66/1000 epochs... 0
# 67/1000 epochs... 0
# 68/1000 epochs... 0
# 69/1000 epochs... 0
# 70/1000 epochs... 0
# 71/1000 epochs... 0
# 72/1000 epochs... 0
# 73/1000 epochs... 0
# 74/1000 epochs... 0
# 75/1000 epochs... 0
# 76/1000 epochs... 0
# 77/1000 epochs... 0
# 78/1000 epochs... 0
# 79/1000 epochs... 0
# 80/1000 epochs... 0
# 81/1000 epochs... 0
# 82/1000 epochs... 0
# 83/1000 epochs... 0
# 84/1000 epochs... 0
# 85/1000 epochs... 0
# 86/1000 epochs... 0
# 87/1000 epochs... 0
# 88/1000 epochs... 0
# 89/1000 epochs... 0
# 90/1000 epochs... 0
# 91/1000 epochs... 0
# 92/1000 epochs... 0
# 93/1000 epochs... 0
# 94/1000 epochs... 0
# 95/1000 epochs... 0
# 96/1000 epochs... 0
# 97/1000 epochs... 0
# 98/1000 epochs... 0
# 99/1000 epochs... 0
# 100/1000 epochs... 0
# 101/1000 epochs... 0
# 102/1000 epochs... 0
# 103/1000 epochs... 0
# 104/1000 epochs... 0
# 105/1000 epochs... 0
# 106/1000 epochs... 0
# 107/1000 epochs... 0
# 108/1000 epochs... 0
# 109/1000 epochs... 0
# 110/1000 epochs... 0
# 111/1000 epochs... 0
# 112/1000 epochs... 0
# 113/1000 epochs... 0
# 114/1000 epochs... 0
# 115/1000 epochs... 0
# 116/1000 epochs... 0
# 117/1000 epochs... 0
# 118/1000 epochs... 0
# 119/1000 epochs... 0
# 120/1000 epochs... 0
# 121/1000 epochs... 0
# 122/1000 epochs... 0
# 123/1000 epochs... 0
# 124/1000 epochs... 0
# 125/1000 epochs... 0
# 126/1000 epochs... 0
# 127/1000 epochs... 0
# 128/1000 epochs... 0
# 129/1000 epochs... 0
# 130/1000 epochs... 0
# 131/1000 epochs... 0
# 132/1000 epochs... 0
# 133/1000 epochs... 0
# 134/1000 epochs... 0
# 135/1000 epochs... 0
# 136/1000 epochs... 0
# 137/1000 epochs... 0
# 138/1000 epochs... 0
# 139/1000 epochs... 0
# 140/1000 epochs... 0
# 141/1000 epochs... 0
# 142/1000 epochs... 0
# 143/1000 epochs... 0
# 144/1000 epochs... 0
# 145/1000 epochs... 0
# 146/1000 epochs... 0
# 147/1000 epochs... 0
# 148/1000 epochs... 0
# 149/1000 epochs... 0
# 150/1000 epochs... 0
# 151/1000 epochs... 0
# 152/1000 epochs... 0
# 153/1000 epochs... 0
# 154/1000 epochs... 0
# 155/1000 epochs... 0
# 156/1000 epochs... 0
# 157/1000 epochs... 0
# 158/1000 epochs... 0
# 159/1000 epochs... 0
# 160/1000 epochs... 0
# 161/1000 epochs... 0
# 162/1000 epochs... 0
# 163/1000 epochs... 0
# 164/1000 epochs... 0
# 165/1000 epochs... 0
# 166/1000 epochs... 0
# 167/1000 epochs... 0
# 168/1000 epochs... 0
# 169/1000 epochs... 0
# 170/1000 epochs... 0
# 171/1000 epochs... 0
# 172/1000 epochs... 0
# 173/1000 epochs... 0
# 174/1000 epochs... 0
# 175/1000 epochs... 0
# 176/1000 epochs... 0
# 177/1000 epochs... 0
# 178/1000 epochs... 0
# 179/1000 epochs... 0
# 180/1000 epochs... 0
# 181/1000 epochs... 0
# 182/1000 epochs... 0
# 183/1000 epochs... 0
# 184/1000 epochs... 0
# 185/1000 epochs... 0
# 186/1000 epochs... 0
# 187/1000 epochs... 0
# 188/1000 epochs... 0
# 189/1000 epochs... 0
# 190/1000 epochs... 0
# 191/1000 epochs... 0
# 192/1000 epochs... 0
# 193/1000 epochs... 0
# 194/1000 epochs... 0
# 195/1000 epochs... 0
# 196/1000 epochs... 0
# 197/1000 epochs... 0
# 198/1000 epochs... 0
# 199/1000 epochs... 0
# 200/1000 epochs... 0
# 201/1000 epochs... 0
# 202/1000 epochs... 0
# 203/1000 epochs... 0
# 204/1000 epochs... 0
# 205/1000 epochs... 0
# 206/1000 epochs... 0
# 207/1000 epochs... 0
# 208/1000 epochs... 0
# 209/1000 epochs... 0
# 210/1000 epochs... 0
# 211/1000 epochs... 0
# 212/1000 epochs... 0
# 213/1000 epochs... 0
# 214/1000 epochs... 0
# 215/1000 epochs... 0
# 216/1000 epochs... 0
# 217/1000 epochs... 0
# 218/1000 epochs... 0
# 219/1000 epochs... 0
# 220/1000 epochs... 0
# 221/1000 epochs... 0
# 222/1000 epochs... 0
# 223/1000 epochs... 0
# 224/1000 epochs... 0
# 225/1000 epochs... 0
# 226/1000 epochs... 0
# 227/1000 epochs... 0
# 228/1000 epochs... 0
# 229/1000 epochs... 0
# 230/1000 epochs... 0
# 231/1000 epochs... 0
# 232/1000 epochs... 0
# 233/1000 epochs... 0
# 234/1000 epochs... 0
# 235/1000 epochs... 0
# 236/1000 epochs... 0
# 237/1000 epochs... 0
# 238/1000 epochs... 0
# 239/1000 epochs... 0
# 240/1000 epochs... 0
# 241/1000 epochs... 0
# 242/1000 epochs... 0
# 243/1000 epochs... 0
# 244/1000 epochs... 0
# 245/1000 epochs... 0
# 246/1000 epochs... 0
# 247/1000 epochs... 0
# 248/1000 epochs... 0
# 249/1000 epochs... 0
# 250/1000 epochs... 0
# 251/1000 epochs... 0
# 252/1000 epochs... 0
# 253/1000 epochs... 0
# 254/1000 epochs... 0
# 255/1000 epochs... 0
# 256/1000 epochs... 0
# 257/1000 epochs... 0
# 258/1000 epochs... 0
# 259/1000 epochs... 0
# 260/1000 epochs... 0
# 261/1000 epochs... 0
# 262/1000 epochs... 0
# 263/1000 epochs... 0
# 264/1000 epochs... 0
# 265/1000 epochs... 0
# 266/1000 epochs... 0
# 267/1000 epochs... 0
# 268/1000 epochs... 0
# 269/1000 epochs... 0
# 270/1000 epochs... 0
# 271/1000 epochs... 0
# 272/1000 epochs... 0
# 273/1000 epochs... 0
# 274/1000 epochs... 0
# 275/1000 epochs... 0
# 276/1000 epochs... 0
# 277/1000 epochs... 0
# 278/1000 epochs... 0
# 279/1000 epochs... 0
# 280/1000 epochs... 0
# 281/1000 epochs... 0
# 282/1000 epochs... 0
# 283/1000 epochs... 0
# 284/1000 epochs... 0
# 285/1000 epochs... 0
# 286/1000 epochs... 0
# 287/1000 epochs... 0
# 288/1000 epochs... 0
# 289/1000 epochs... 0
# 290/1000 epochs... 0
# 291/1000 epochs... 0
# 292/1000 epochs... 0
# 293/1000 epochs... 0
# 294/1000 epochs... 0
# 295/1000 epochs... 0
# 296/1000 epochs... 0
# 297/1000 epochs... 0
# 298/1000 epochs... 0
# 299/1000 epochs... 0
# 300/1000 epochs... 0
# 301/1000 epochs... 0
# 302/1000 epochs... 0
# 303/1000 epochs... 0
# 304/1000 epochs... 0
# 305/1000 epochs... 0
# 306/1000 epochs... 0
# 307/1000 epochs... 0
# 308/1000 epochs... 0
# 309/1000 epochs... 0
# 310/1000 epochs... 0
# 311/1000 epochs... 0
# 312/1000 epochs... 0
# 313/1000 epochs... 0
# 314/1000 epochs... 0
# 315/1000 epochs... 0
# 316/1000 epochs... 0
# 317/1000 epochs... 0
# 318/1000 epochs... 0
# 319/1000 epochs... 0
# 320/1000 epochs... 0
# 321/1000 epochs... 0
# 322/1000 epochs... 0
# 323/1000 epochs... 0
# 324/1000 epochs... 0
# 325/1000 epochs... 0
# 326/1000 epochs... 0
# 327/1000 epochs... 0
# 328/1000 epochs... 0
# 329/1000 epochs... 0
# 330/1000 epochs... 0
# 331/1000 epochs... 0
# 332/1000 epochs... 0
# 333/1000 epochs... 0
# 334/1000 epochs... 0
# 335/1000 epochs... 0
# 336/1000 epochs... 0
# 337/1000 epochs... 0
# 338/1000 epochs... 0
# 339/1000 epochs... 0
# 340/1000 epochs... 0
# 341/1000 epochs... 0
# 342/1000 epochs... 0
# 343/1000 epochs... 0
# 344/1000 epochs... 0
# 345/1000 epochs... 0
# 346/1000 epochs... 0
# 347/1000 epochs... 0
# 348/1000 epochs... 0
# 349/1000 epochs... 0
# 350/1000 epochs... 0
# 351/1000 epochs... 0
# 352/1000 epochs... 0
# 353/1000 epochs... 0
# 354/1000 epochs... 0
# 355/1000 epochs... 0
# 356/1000 epochs... 0
# 357/1000 epochs... 0
# 358/1000 epochs... 0
# 359/1000 epochs... 0
# 360/1000 epochs... 0
# 361/1000 epochs... 0
# 362/1000 epochs... 0
# 363/1000 epochs... 0
# 364/1000 epochs... 0
# 365/1000 epochs... 0
# 366/1000 epochs... 0
# 367/1000 epochs... 0
# 368/1000 epochs... 0
# 369/1000 epochs... 0
# 370/1000 epochs... 0
# 371/1000 epochs... 0
# 372/1000 epochs... 0
# 373/1000 epochs... 0
# 374/1000 epochs... 0
# 375/1000 epochs... 0
# 376/1000 epochs... 0
# 377/1000 epochs... 0
# 378/1000 epochs... 0
# 379/1000 epochs... 0
# 380/1000 epochs... 0
# 381/1000 epochs... 0
# 382/1000 epochs... 0
# 383/1000 epochs... 0
# 384/1000 epochs... 0
# 385/1000 epochs... 0
# 386/1000 epochs... 0
# 387/1000 epochs... 0
# 388/1000 epochs... 0
# 389/1000 epochs... 0
# 390/1000 epochs... 0
# 391/1000 epochs... 0
# 392/1000 epochs... 0
# 393/1000 epochs... 0
# 394/1000 epochs... 0
# 395/1000 epochs... 0
# 396/1000 epochs... 0
# 397/1000 epochs... 0
# 398/1000 epochs... 0
# 399/1000 epochs... 0
# 400/1000 epochs... 0
# 401/1000 epochs... 0
# 402/1000 epochs... 0
# 403/1000 epochs... 0
# 404/1000 epochs... 0
# 405/1000 epochs... 0
# 406/1000 epochs... 0
# 407/1000 epochs... 0
# 408/1000 epochs... 0
# 409/1000 epochs... 0
# 410/1000 epochs... 0
# 411/1000 epochs... 0
# 412/1000 epochs... 0
# 413/1000 epochs... 0
# 414/1000 epochs... 0
# 415/1000 epochs... 0
# 416/1000 epochs... 0
# 417/1000 epochs... 0
# 418/1000 epochs... 0
# 419/1000 epochs... 0
# 420/1000 epochs... 0
# 421/1000 epochs... 0
# 422/1000 epochs... 0
# 423/1000 epochs... 0
# 424/1000 epochs... 0
# 425/1000 epochs... 0
# 426/1000 epochs... 0
# 427/1000 epochs... 0
# 428/1000 epochs... 0
# 429/1000 epochs... 0
# 430/1000 epochs... 0
# 431/1000 epochs... 0
# 432/1000 epochs... 0
# 433/1000 epochs... 0
# 434/1000 epochs... 0
# 435/1000 epochs... 0
# 436/1000 epochs... 0
# 437/1000 epochs... 0
# 438/1000 epochs... 0
# 439/1000 epochs... 0
# 440/1000 epochs... 0
# 441/1000 epochs... 0
# 442/1000 epochs... 0
# 443/1000 epochs... 0
# 444/1000 epochs... 0
# 445/1000 epochs... 0
# 446/1000 epochs... 0
# 447/1000 epochs... 0
# 448/1000 epochs... 0
# 449/1000 epochs... 0
# 450/1000 epochs... 0
# 451/1000 epochs... 0
# 452/1000 epochs... 0
# 453/1000 epochs... 0
# 454/1000 epochs... 0
# 455/1000 epochs... 0
# 456/1000 epochs... 0
# 457/1000 epochs... 0
# 458/1000 epochs... 0
# 459/1000 epochs... 0
# 460/1000 epochs... 0
# 461/1000 epochs... 0
# 462/1000 epochs... 0
# 463/1000 epochs... 0
# 464/1000 epochs... 0
# 465/1000 epochs... 0
# 466/1000 epochs... 0
# 467/1000 epochs... 0
# 468/1000 epochs... 0
# 469/1000 epochs... 0
# 470/1000 epochs... 0
# 471/1000 epochs... 0
# 472/1000 epochs... 0
# 473/1000 epochs... 0
# 474/1000 epochs... 0
# 475/1000 epochs... 0
# 476/1000 epochs... 0
# 477/1000 epochs... 0
# 478/1000 epochs... 0
# 479/1000 epochs... 0
# 480/1000 epochs... 0
# 481/1000 epochs... 0
# 482/1000 epochs... 0
# 483/1000 epochs... 0
# 484/1000 epochs... 0
# 485/1000 epochs... 0
# 486/1000 epochs... 0
# 487/1000 epochs... 0
# 488/1000 epochs... 0
# 489/1000 epochs... 0
# 490/1000 epochs... 0
# 491/1000 epochs... 0
# 492/1000 epochs... 0
# 493/1000 epochs... 0
# 494/1000 epochs... 0
# 495/1000 epochs... 0
# 496/1000 epochs... 0
# 497/1000 epochs... 0
# 498/1000 epochs... 0
# 499/1000 epochs... 0
# 500/1000 epochs... 0
# 501/1000 epochs... 0
# 502/1000 epochs... 0
# 503/1000 epochs... 0
# 504/1000 epochs... 0
# 505/1000 epochs... 0
# 506/1000 epochs... 0
# 507/1000 epochs... 0
# 508/1000 epochs... 0
# 509/1000 epochs... 0
# 510/1000 epochs... 0
# 511/1000 epochs... 0
# 512/1000 epochs... 0
# 513/1000 epochs... 0
# 514/1000 epochs... 0
# 515/1000 epochs... 0
# 516/1000 epochs... 0
# 517/1000 epochs... 0
# 518/1000 epochs... 0
# 519/1000 epochs... 0
# 520/1000 epochs... 0
# 521/1000 epochs... 0
# 522/1000 epochs... 0
# 523/1000 epochs... 0
# 524/1000 epochs... 0
# 525/1000 epochs... 0
# 526/1000 epochs... 0
# 527/1000 epochs... 0
# 528/1000 epochs... 0
# 529/1000 epochs... 0
# 530/1000 epochs... 0
# 531/1000 epochs... 0
# 532/1000 epochs... 0
# 533/1000 epochs... 0
# 534/1000 epochs... 0
# 535/1000 epochs... 0
# 536/1000 epochs... 0
# 537/1000 epochs... 0
# 538/1000 epochs... 0
# 539/1000 epochs... 0
# 540/1000 epochs... 0
# 541/1000 epochs... 0
# 542/1000 epochs... 0
# 543/1000 epochs... 0
# 544/1000 epochs... 0
# 545/1000 epochs... 0
# 546/1000 epochs... 0
# 547/1000 epochs... 0
# 548/1000 epochs... 0
# 549/1000 epochs... 0
# 550/1000 epochs... 0
# 551/1000 epochs... 0
# 552/1000 epochs... 0
# 553/1000 epochs... 0
# 554/1000 epochs... 0
# 555/1000 epochs... 0
# 556/1000 epochs... 0
# 557/1000 epochs... 0
# 558/1000 epochs... 0
# 559/1000 epochs... 0
# 560/1000 epochs... 0
# 561/1000 epochs... 0
# 562/1000 epochs... 0
# 563/1000 epochs... 0
# 564/1000 epochs... 0
# 565/1000 epochs... 0
# 566/1000 epochs... 0
# 567/1000 epochs... 0
# 568/1000 epochs... 0
# 569/1000 epochs... 0
# 570/1000 epochs... 0
# 571/1000 epochs... 0
# 572/1000 epochs... 0
# 573/1000 epochs... 0
# 574/1000 epochs... 0
# 575/1000 epochs... 0
# 576/1000 epochs... 0
# 577/1000 epochs... 0
# 578/1000 epochs... 0
# 579/1000 epochs... 0
# 580/1000 epochs... 0
# 581/1000 epochs... 0
# 582/1000 epochs... 0
# 583/1000 epochs... 0
# 584/1000 epochs... 0
# 585/1000 epochs... 0
# 586/1000 epochs... 0
# 587/1000 epochs... 0
# 588/1000 epochs... 0
# 589/1000 epochs... 0
# 590/1000 epochs... 0
# 591/1000 epochs... 0
# 592/1000 epochs... 0
# 593/1000 epochs... 0
# 594/1000 epochs... 0
# 595/1000 epochs... 0
# 596/1000 epochs... 0
# 597/1000 epochs... 0
# 598/1000 epochs... 0
# 599/1000 epochs... 0
# 600/1000 epochs... 0
# 601/1000 epochs... 0
# 602/1000 epochs... 0
# 603/1000 epochs... 0
# 604/1000 epochs... 0
# 605/1000 epochs... 0
# 606/1000 epochs... 0
# 607/1000 epochs... 0
# 608/1000 epochs... 0
# 609/1000 epochs... 0
# 610/1000 epochs... 0
# 611/1000 epochs... 0
# 612/1000 epochs... 0
# 613/1000 epochs... 0
# 614/1000 epochs... 0
# 615/1000 epochs... 0
# 616/1000 epochs... 0
# 617/1000 epochs... 0
# 618/1000 epochs... 0
# 619/1000 epochs... 0
# 620/1000 epochs... 0
# 621/1000 epochs... 0
# 622/1000 epochs... 0
# 623/1000 epochs... 0
# 624/1000 epochs... 0
# 625/1000 epochs... 0
# 626/1000 epochs... 0
# 627/1000 epochs... 0
# 628/1000 epochs... 0
# 629/1000 epochs... 0
# 630/1000 epochs... 0
# 631/1000 epochs... 0
# 632/1000 epochs... 0
# 633/1000 epochs... 0
# 634/1000 epochs... 0
# 635/1000 epochs... 0
# 636/1000 epochs... 0
# 637/1000 epochs... 0
# 638/1000 epochs... 0
# 639/1000 epochs... 0
# 640/1000 epochs... 0
# 641/1000 epochs... 0
# 642/1000 epochs... 0
# 643/1000 epochs... 0
# 644/1000 epochs... 0
# 645/1000 epochs... 0
# 646/1000 epochs... 0
# 647/1000 epochs... 0
# 648/1000 epochs... 0
# 649/1000 epochs... 0
# 650/1000 epochs... 0
# 651/1000 epochs... 0
# 652/1000 epochs... 0
# 653/1000 epochs... 0
# 654/1000 epochs... 0
# 655/1000 epochs... 0
# 656/1000 epochs... 0
# 657/1000 epochs... 0
# 658/1000 epochs... 0
# 659/1000 epochs... 0
# 660/1000 epochs... 0
# 661/1000 epochs... 0
# 662/1000 epochs... 0
# 663/1000 epochs... 0
# 664/1000 epochs... 0
# 665/1000 epochs... 0
# 666/1000 epochs... 0
# 667/1000 epochs... 0
# 668/1000 epochs... 0
# 669/1000 epochs... 0
# 670/1000 epochs... 0
# 671/1000 epochs... 0
# 672/1000 epochs... 0
# 673/1000 epochs... 0
# 674/1000 epochs... 0
# 675/1000 epochs... 0
# 676/1000 epochs... 0
# 677/1000 epochs... 0
# 678/1000 epochs... 0
# 679/1000 epochs... 0
# 680/1000 epochs... 0
# 681/1000 epochs... 0
# 682/1000 epochs... 0
# 683/1000 epochs... 0
# 684/1000 epochs... 0
# 685/1000 epochs... 0
# 686/1000 epochs... 0
# 687/1000 epochs... 0
# 688/1000 epochs... 0
# 689/1000 epochs... 0
# 690/1000 epochs... 0
# 691/1000 epochs... 0
# 692/1000 epochs... 0
# 693/1000 epochs... 0
# 694/1000 epochs... 0
# 695/1000 epochs... 0
# 696/1000 epochs... 0
# 697/1000 epochs... 0
# 698/1000 epochs... 0
# 699/1000 epochs... 0
# 700/1000 epochs... 0
# 701/1000 epochs... 0
# 702/1000 epochs... 0
# 703/1000 epochs... 0
# 704/1000 epochs... 0
# 705/1000 epochs... 0
# 706/1000 epochs... 0
# 707/1000 epochs... 0
# 708/1000 epochs... 0
# 709/1000 epochs... 0
# 710/1000 epochs... 0
# 711/1000 epochs... 0
# 712/1000 epochs... 0
# 713/1000 epochs... 0
# 714/1000 epochs... 0
# 715/1000 epochs... 0
# 716/1000 epochs... 0
# 717/1000 epochs... 0
# 718/1000 epochs... 0
# 719/1000 epochs... 0
# 720/1000 epochs... 0
# 721/1000 epochs... 0
# 722/1000 epochs... 0
# 723/1000 epochs... 0
# 724/1000 epochs... 0
# 725/1000 epochs... 0
# 726/1000 epochs... 0
# 727/1000 epochs... 0
# 728/1000 epochs... 0
# 729/1000 epochs... 0
# 730/1000 epochs... 0
# 731/1000 epochs... 0
# 732/1000 epochs... 0
# 733/1000 epochs... 0
# 734/1000 epochs... 0
# 735/1000 epochs... 0
# 736/1000 epochs... 0
# 737/1000 epochs... 0
# 738/1000 epochs... 0
# 739/1000 epochs... 0
# 740/1000 epochs... 0
# 741/1000 epochs... 0
# 742/1000 epochs... 0
# 743/1000 epochs... 0
# 744/1000 epochs... 0
# 745/1000 epochs... 0
# 746/1000 epochs... 0
# 747/1000 epochs... 0
# 748/1000 epochs... 0
# 749/1000 epochs... 0
# 750/1000 epochs... 0
# 751/1000 epochs... 0
# 752/1000 epochs... 0
# 753/1000 epochs... 0
# 754/1000 epochs... 0
# 755/1000 epochs... 0
# 756/1000 epochs... 0
# 757/1000 epochs... 0
# 758/1000 epochs... 0
# 759/1000 epochs... 0
# 760/1000 epochs... 0
# 761/1000 epochs... 0
# 762/1000 epochs... 0
# 763/1000 epochs... 0
# 764/1000 epochs... 0
# 765/1000 epochs... 0
# 766/1000 epochs... 0
# 767/1000 epochs... 0
# 768/1000 epochs... 0
# 769/1000 epochs... 0
# 770/1000 epochs... 0
# 771/1000 epochs... 0
# 772/1000 epochs... 0
# 773/1000 epochs... 0
# 774/1000 epochs... 0
# 775/1000 epochs... 0
# 776/1000 epochs... 0
# 777/1000 epochs... 0
# 778/1000 epochs... 0
# 779/1000 epochs... 0
# 780/1000 epochs... 0
# 781/1000 epochs... 0
# 782/1000 epochs... 0
# 783/1000 epochs... 0
# 784/1000 epochs... 0
# 785/1000 epochs... 0
# 786/1000 epochs... 0
# 787/1000 epochs... 0
# 788/1000 epochs... 0
# 789/1000 epochs... 0
# 790/1000 epochs... 0
# 791/1000 epochs... 0
# 792/1000 epochs... 0
# 793/1000 epochs... 0
# 794/1000 epochs... 0
# 795/1000 epochs... 0
# 796/1000 epochs... 0
# 797/1000 epochs... 0
# 798/1000 epochs... 0
# 799/1000 epochs... 0
# 800/1000 epochs... 0
# tcmalloc: large alloc 1425391616 bytes == 0x919c2000 @  0x7f1fe58801e7 0x7f1fe2cfd5e1 0x7f1fe2d61c78 0x7f1fe2d61f37 0x7f1fe2df9f28 0x50a635 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1fe547db97 0x5b250a
# tcmalloc: large alloc 1425391616 bytes == 0x919c2000 @  0x7f1fe58801e7 0x7f1fe2cfd5e1 0x7f1fe2d61c78 0x7f1fe2d61f37 0x7f1fe2df9f28 0x50a635 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1fe547db97 0x5b250a
# 2020-06-07 09:03:45.099410: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x1c2a66000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# tcmalloc: large alloc 2710806528 bytes == 0x3ee1c6000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f508ce2a4 0x7f1f508cf107 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# Entity:
# For each left:
# Hits@1: 76.64%
# Hits@10: 90.39%
# Hits@50: 94.61%
# Hits@100: 96.03%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.74%
# Hits@50: 94.24%
# Hits@100: 95.76%
# Relation:
# For each left:
# Hits@1: 88.85%
# Hits@10: 92.44%
# Hits@50: 94.14%
# Hits@100: 96.79%
# For each right:
# Hits@1: 79.96%
# Hits@10: 85.07%
# Hits@50: 90.55%
# Hits@100: 95.27%
# 801/1000 epochs... 0.02845647
# 2020-06-07 09:05:18.752871: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x1b39bc000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# tcmalloc: large alloc 2710806528 bytes == 0x48ea08000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f508ce2a4 0x7f1f508cf107 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# 802/1000 epochs... 0.02845647
# 2020-06-07 09:05:23.196763: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a18a000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# 803/1000 epochs... 0.02845647
# 2020-06-07 09:05:26.485944: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a18a000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# 804/1000 epochs... 0.02845647
# 2020-06-07 09:05:29.782174: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 3614400000 exceeds 10% of system memory.
# tcmalloc: large alloc 3614400512 bytes == 0x13a18a000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# 805/1000 epochs... 0.02845647
# tcmalloc: large alloc 3614400512 bytes == 0x13a18a000 @  0x7f1fe5862b6b 0x7f1fe5882379 0x7f1f4ca7a977 0x7f1f4c86808f 0x7f1f4c72d42b 0x7f1f4c6f2e16 0x7f1f4c6f3ca3 0x7f1f4c6f3e77 0x7f1f5028ab33 0x7f1f4c9ac136 0x7f1f4c99e785 0x7f1f4ca5c8b9 0x7f1f4ca59f88 0x7f1fe41626df 0x7f1fe52446db 0x7f1fe557d88f
# 806/1000 epochs... 0.02845647
# 807/1000 epochs... 0.02845647
# 808/1000 epochs... 0.02845647
# 809/1000 epochs... 0.02845647
# 810/1000 epochs... 0.02845647
# Entity:
# For each left:
# Hits@1: 76.63%
# Hits@10: 90.42%
# Hits@50: 94.59%
# Hits@100: 95.99%
# For each right:
# Hits@1: 73.07%
# Hits@10: 88.75%
# Hits@50: 94.22%
# Hits@100: 95.76%
# Relation:
# For each left:
# Hits@1: 88.09%
# Hits@10: 92.44%
# Hits@50: 93.57%
# Hits@100: 96.03%
# For each right:
# Hits@1: 79.40%
# Hits@10: 84.50%
# Hits@50: 90.17%
# Hits@100: 94.33%
# 811/1000 epochs... 0.028052848
# 812/1000 epochs... 0.028052848
# 813/1000 epochs... 0.028052848
# 814/1000 epochs... 0.028052848
# 815/1000 epochs... 0.028052848
# 816/1000 epochs... 0.028052848
# 817/1000 epochs... 0.028052848
# 818/1000 epochs... 0.028052848
# 819/1000 epochs... 0.028052848
# 820/1000 epochs... 0.028052848
# Entity:
# For each left:
# Hits@1: 76.70%
# Hits@10: 90.47%
# Hits@50: 94.61%
# Hits@100: 95.97%
# For each right:
# Hits@1: 73.07%
# Hits@10: 88.74%
# Hits@50: 94.21%
# Hits@100: 95.73%
# Relation:
# For each left:
# Hits@1: 87.71%
# Hits@10: 92.25%
# Hits@50: 93.57%
# Hits@100: 94.90%
# For each right:
# Hits@1: 77.88%
# Hits@10: 83.74%
# Hits@50: 89.60%
# Hits@100: 93.76%
# 821/1000 epochs... 0.0276673
# 822/1000 epochs... 0.0276673
# 823/1000 epochs... 0.0276673
# 824/1000 epochs... 0.0276673
# 825/1000 epochs... 0.0276673
# 826/1000 epochs... 0.0276673
# 827/1000 epochs... 0.0276673
# 828/1000 epochs... 0.0276673
# 829/1000 epochs... 0.0276673
# 830/1000 epochs... 0.0276673
# Entity:
# For each left:
# Hits@1: 76.68%
# Hits@10: 90.45%
# Hits@50: 94.58%
# Hits@100: 95.93%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.71%
# Hits@50: 94.23%
# Hits@100: 95.70%
# Relation:
# For each left:
# Hits@1: 86.39%
# Hits@10: 91.68%
# Hits@50: 93.57%
# Hits@100: 94.71%
# For each right:
# Hits@1: 76.37%
# Hits@10: 82.80%
# Hits@50: 88.66%
# Hits@100: 93.38%
# 831/1000 epochs... 0.02729826
# 832/1000 epochs... 0.02729826
# 833/1000 epochs... 0.02729826
# 834/1000 epochs... 0.02729826
# 835/1000 epochs... 0.02729826
# 836/1000 epochs... 0.02729826
# 837/1000 epochs... 0.02729826
# 838/1000 epochs... 0.02729826
# 839/1000 epochs... 0.02729826
# 840/1000 epochs... 0.02729826
# Entity:
# For each left:
# Hits@1: 76.69%
# Hits@10: 90.38%
# Hits@50: 94.59%
# Hits@100: 95.92%
# For each right:
# Hits@1: 73.03%
# Hits@10: 88.71%
# Hits@50: 94.22%
# Hits@100: 95.70%
# Relation:
# For each left:
# Hits@1: 85.44%
# Hits@10: 90.36%
# Hits@50: 93.57%
# Hits@100: 94.52%
# For each right:
# Hits@1: 75.05%
# Hits@10: 81.85%
# Hits@50: 87.52%
# Hits@100: 92.44%
# 841/1000 epochs... 0.02694512
# 842/1000 epochs... 0.02694512
# 843/1000 epochs... 0.02694512
# 844/1000 epochs... 0.02694512
# 845/1000 epochs... 0.02694512
# 846/1000 epochs... 0.02694512
# 847/1000 epochs... 0.02694512
# 848/1000 epochs... 0.02694512
# 849/1000 epochs... 0.02694512
# 850/1000 epochs... 0.02694512
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.35%
# Hits@50: 94.61%
# Hits@100: 95.91%
# For each right:
# Hits@1: 73.11%
# Hits@10: 88.72%
# Hits@50: 94.18%
# Hits@100: 95.62%
# Relation:
# For each left:
# Hits@1: 84.88%
# Hits@10: 89.79%
# Hits@50: 93.19%
# Hits@100: 94.33%
# For each right:
# Hits@1: 73.53%
# Hits@10: 80.91%
# Hits@50: 86.01%
# Hits@100: 91.87%
# 851/1000 epochs... 0.026607191
# 852/1000 epochs... 0.026607191
# 853/1000 epochs... 0.026607191
# 854/1000 epochs... 0.026607191
# 855/1000 epochs... 0.026607191
# 856/1000 epochs... 0.026607191
# 857/1000 epochs... 0.026607191
# 858/1000 epochs... 0.026607191
# 859/1000 epochs... 0.026607191
# 860/1000 epochs... 0.026607191
# Entity:
# For each left:
# Hits@1: 76.76%
# Hits@10: 90.38%
# Hits@50: 94.58%
# Hits@100: 95.87%
# For each right:
# Hits@1: 73.15%
# Hits@10: 88.78%
# Hits@50: 94.16%
# Hits@100: 95.61%
# Relation:
# For each left:
# Hits@1: 84.31%
# Hits@10: 89.41%
# Hits@50: 92.44%
# Hits@100: 94.14%
# For each right:
# Hits@1: 73.16%
# Hits@10: 79.40%
# Hits@50: 85.44%
# Hits@100: 91.49%
# 861/1000 epochs... 0.026283126
# 862/1000 epochs... 0.026283126
# 863/1000 epochs... 0.026283126
# 864/1000 epochs... 0.026283126
# 865/1000 epochs... 0.026283126
# 866/1000 epochs... 0.026283126
# 867/1000 epochs... 0.026283126
# 868/1000 epochs... 0.026283126
# 869/1000 epochs... 0.026283126
# 870/1000 epochs... 0.026283126
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.40%
# Hits@50: 94.54%
# Hits@100: 95.81%
# For each right:
# Hits@1: 73.20%
# Hits@10: 88.79%
# Hits@50: 94.13%
# Hits@100: 95.57%
# Relation:
# For each left:
# Hits@1: 83.55%
# Hits@10: 88.66%
# Hits@50: 92.06%
# Hits@100: 93.95%
# For each right:
# Hits@1: 72.40%
# Hits@10: 78.26%
# Hits@50: 84.50%
# Hits@100: 90.74%
# 871/1000 epochs... 0.025971904
# 872/1000 epochs... 0.025971904
# 873/1000 epochs... 0.025971904
# 874/1000 epochs... 0.025971904
# 875/1000 epochs... 0.025971904
# 876/1000 epochs... 0.025971904
# 877/1000 epochs... 0.025971904
# 878/1000 epochs... 0.025971904
# 879/1000 epochs... 0.025971904
# 880/1000 epochs... 0.025971904
# Entity:
# For each left:
# Hits@1: 76.74%
# Hits@10: 90.41%
# Hits@50: 94.59%
# Hits@100: 95.78%
# For each right:
# Hits@1: 73.15%
# Hits@10: 88.81%
# Hits@50: 94.12%
# Hits@100: 95.56%
# Relation:
# For each left:
# Hits@1: 83.18%
# Hits@10: 88.09%
# Hits@50: 91.68%
# Hits@100: 93.57%
# For each right:
# Hits@1: 71.27%
# Hits@10: 77.69%
# Hits@50: 83.18%
# Hits@100: 89.98%
# 881/1000 epochs... 0.025672674
# 882/1000 epochs... 0.025672674
# 883/1000 epochs... 0.025672674
# 884/1000 epochs... 0.025672674
# 885/1000 epochs... 0.025672674
# 886/1000 epochs... 0.025672674
# 887/1000 epochs... 0.025672674
# 888/1000 epochs... 0.025672674
# 889/1000 epochs... 0.025672674
# 890/1000 epochs... 0.025672674
# Entity:
# For each left:
# Hits@1: 76.72%
# Hits@10: 90.40%
# Hits@50: 94.58%
# Hits@100: 95.77%
# For each right:
# Hits@1: 73.11%
# Hits@10: 88.82%
# Hits@50: 94.07%
# Hits@100: 95.54%
# Relation:
# For each left:
# Hits@1: 83.18%
# Hits@10: 87.90%
# Hits@50: 90.93%
# Hits@100: 93.19%
# For each right:
# Hits@1: 70.13%
# Hits@10: 77.13%
# Hits@50: 82.42%
# Hits@100: 89.41%
# 891/1000 epochs... 0.025385465
# 892/1000 epochs... 0.025385465
# 893/1000 epochs... 0.025385465
# 894/1000 epochs... 0.025385465
# 895/1000 epochs... 0.025385465
# 896/1000 epochs... 0.025385465
# 897/1000 epochs... 0.025385465
# 898/1000 epochs... 0.025385465
# 899/1000 epochs... 0.025385465
# 900/1000 epochs... 0.025385465
# Entity:
# For each left:
# Hits@1: 76.83%
# Hits@10: 90.39%
# Hits@50: 94.55%
# Hits@100: 95.75%
# For each right:
# Hits@1: 73.12%
# Hits@10: 88.78%
# Hits@50: 94.04%
# Hits@100: 95.55%
# Relation:
# For each left:
# Hits@1: 82.42%
# Hits@10: 87.90%
# Hits@50: 90.55%
# Hits@100: 93.19%
# For each right:
# Hits@1: 69.38%
# Hits@10: 76.37%
# Hits@50: 81.47%
# Hits@100: 88.47%
# 901/1000 epochs... 0.02511039
# 902/1000 epochs... 0.02511039
# 903/1000 epochs... 0.02511039
# 904/1000 epochs... 0.02511039
# 905/1000 epochs... 0.02511039
# 906/1000 epochs... 0.02511039
# 907/1000 epochs... 0.02511039
# 908/1000 epochs... 0.02511039
# 909/1000 epochs... 0.02511039
# 910/1000 epochs... 0.02511039
# Entity:
# For each left:
# Hits@1: 76.87%
# Hits@10: 90.32%
# Hits@50: 94.52%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.09%
# Hits@10: 88.77%
# Hits@50: 94.01%
# Hits@100: 95.52%
# Relation:
# For each left:
# Hits@1: 82.04%
# Hits@10: 86.96%
# Hits@50: 90.36%
# Hits@100: 93.01%
# For each right:
# Hits@1: 69.00%
# Hits@10: 75.61%
# Hits@50: 81.29%
# Hits@100: 87.33%
# 911/1000 epochs... 0.024846504
# 912/1000 epochs... 0.024846504
# 913/1000 epochs... 0.024846504
# 914/1000 epochs... 0.024846504
# 915/1000 epochs... 0.024846504
# 916/1000 epochs... 0.024846504
# 917/1000 epochs... 0.024846504
# 918/1000 epochs... 0.024846504
# 919/1000 epochs... 0.024846504
# 920/1000 epochs... 0.024846504
# Entity:
# For each left:
# Hits@1: 76.85%
# Hits@10: 90.29%
# Hits@50: 94.53%
# Hits@100: 95.69%
# For each right:
# Hits@1: 73.17%
# Hits@10: 88.72%
# Hits@50: 93.97%
# Hits@100: 95.49%
# Relation:
# For each left:
# Hits@1: 81.10%
# Hits@10: 86.39%
# Hits@50: 89.79%
# Hits@100: 92.82%
# For each right:
# Hits@1: 68.24%
# Hits@10: 75.05%
# Hits@50: 80.91%
# Hits@100: 86.01%
# 921/1000 epochs... 0.024593962
# 922/1000 epochs... 0.024593962
# 923/1000 epochs... 0.024593962
# 924/1000 epochs... 0.024593962
# 925/1000 epochs... 0.024593962
# 926/1000 epochs... 0.024593962
# 927/1000 epochs... 0.024593962
# 928/1000 epochs... 0.024593962
# 929/1000 epochs... 0.024593962
# 930/1000 epochs... 0.024593962
# Entity:
# For each left:
# Hits@1: 76.93%
# Hits@10: 90.30%
# Hits@50: 94.50%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.24%
# Hits@10: 88.77%
# Hits@50: 93.94%
# Hits@100: 95.47%
# Relation:
# For each left:
# Hits@1: 80.53%
# Hits@10: 85.44%
# Hits@50: 89.41%
# Hits@100: 92.63%
# For each right:
# Hits@1: 67.49%
# Hits@10: 74.29%
# Hits@50: 80.53%
# Hits@100: 84.88%
# 931/1000 epochs... 0.024350898
# 932/1000 epochs... 0.024350898
# 933/1000 epochs... 0.024350898
# 934/1000 epochs... 0.024350898
# 935/1000 epochs... 0.024350898
# 936/1000 epochs... 0.024350898
# 937/1000 epochs... 0.024350898
# 938/1000 epochs... 0.024350898
# 939/1000 epochs... 0.024350898
# 940/1000 epochs... 0.024350898
# Entity:
# For each left:
# Hits@1: 76.90%
# Hits@10: 90.26%
# Hits@50: 94.49%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.27%
# Hits@10: 88.74%
# Hits@50: 93.92%
# Hits@100: 95.44%
# Relation:
# For each left:
# Hits@1: 79.96%
# Hits@10: 85.07%
# Hits@50: 89.41%
# Hits@100: 92.25%
# For each right:
# Hits@1: 66.73%
# Hits@10: 73.16%
# Hits@50: 79.96%
# Hits@100: 84.12%
# 941/1000 epochs... 0.024118384
# 942/1000 epochs... 0.024118384
# 943/1000 epochs... 0.024118384
# 944/1000 epochs... 0.024118384
# 945/1000 epochs... 0.024118384
# 946/1000 epochs... 0.024118384
# 947/1000 epochs... 0.024118384
# 948/1000 epochs... 0.024118384
# 949/1000 epochs... 0.024118384
# 950/1000 epochs... 0.024118384
# Entity:
# For each left:
# Hits@1: 76.85%
# Hits@10: 90.22%
# Hits@50: 94.50%
# Hits@100: 95.70%
# For each right:
# Hits@1: 73.25%
# Hits@10: 88.75%
# Hits@50: 93.90%
# Hits@100: 95.43%
# Relation:
# For each left:
# Hits@1: 78.83%
# Hits@10: 84.69%
# Hits@50: 88.47%
# Hits@100: 91.68%
# For each right:
# Hits@1: 65.60%
# Hits@10: 72.59%
# Hits@50: 79.40%
# Hits@100: 83.18%
# 951/1000 epochs... 0.023895346
# 952/1000 epochs... 0.023895346
# 953/1000 epochs... 0.023895346
# 954/1000 epochs... 0.023895346
# 955/1000 epochs... 0.023895346
# 956/1000 epochs... 0.023895346
# 957/1000 epochs... 0.023895346
# 958/1000 epochs... 0.023895346
# 959/1000 epochs... 0.023895346
# 960/1000 epochs... 0.023895346
# Entity:
# For each left:
# Hits@1: 76.84%
# Hits@10: 90.22%
# Hits@50: 94.49%
# Hits@100: 95.63%
# For each right:
# Hits@1: 73.29%
# Hits@10: 88.69%
# Hits@50: 93.90%
# Hits@100: 95.41%
# Relation:
# For each left:
# Hits@1: 78.45%
# Hits@10: 83.74%
# Hits@50: 87.71%
# Hits@100: 91.30%
# For each right:
# Hits@1: 65.60%
# Hits@10: 71.64%
# Hits@50: 79.40%
# Hits@100: 83.36%
# 961/1000 epochs... 0.02368168
# 962/1000 epochs... 0.02368168
# 963/1000 epochs... 0.02368168
# 964/1000 epochs... 0.02368168
# 965/1000 epochs... 0.02368168
# 966/1000 epochs... 0.02368168
# 967/1000 epochs... 0.02368168
# 968/1000 epochs... 0.02368168
# 969/1000 epochs... 0.02368168
# 970/1000 epochs... 0.02368168
# Entity:
# For each left:
# Hits@1: 76.86%
# Hits@10: 90.18%
# Hits@50: 94.49%
# Hits@100: 95.62%
# For each right:
# Hits@1: 73.26%
# Hits@10: 88.60%
# Hits@50: 93.88%
# Hits@100: 95.40%
# Relation:
# For each left:
# Hits@1: 78.45%
# Hits@10: 82.99%
# Hits@50: 87.33%
# Hits@100: 91.12%
# For each right:
# Hits@1: 65.03%
# Hits@10: 71.46%
# Hits@50: 79.21%
# Hits@100: 82.42%
# 971/1000 epochs... 0.023476541
# 972/1000 epochs... 0.023476541
# 973/1000 epochs... 0.023476541
# 974/1000 epochs... 0.023476541
# 975/1000 epochs... 0.023476541
# 976/1000 epochs... 0.023476541
# 977/1000 epochs... 0.023476541
# 978/1000 epochs... 0.023476541
# 979/1000 epochs... 0.023476541
# 980/1000 epochs... 0.023476541
# Entity:
# For each left:
# Hits@1: 76.89%
# Hits@10: 90.12%
# Hits@50: 94.47%
# Hits@100: 95.63%
# For each right:
# Hits@1: 73.31%
# Hits@10: 88.55%
# Hits@50: 93.86%
# Hits@100: 95.36%
# Relation:
# For each left:
# Hits@1: 77.69%
# Hits@10: 82.99%
# Hits@50: 86.77%
# Hits@100: 90.36%
# For each right:
# Hits@1: 64.08%
# Hits@10: 71.27%
# Hits@50: 78.83%
# Hits@100: 82.23%
# 981/1000 epochs... 0.023281025
# 982/1000 epochs... 0.023281025
# 983/1000 epochs... 0.023281025
# 984/1000 epochs... 0.023281025
# 985/1000 epochs... 0.023281025
# 986/1000 epochs... 0.023281025
# 987/1000 epochs... 0.023281025
# 988/1000 epochs... 0.023281025
# 989/1000 epochs... 0.023281025
# 990/1000 epochs... 0.023281025
# Entity:
# For each left:
# Hits@1: 76.90%
# Hits@10: 90.12%
# Hits@50: 94.44%
# Hits@100: 95.60%
# For each right:
# Hits@1: 73.30%
# Hits@10: 88.50%
# Hits@50: 93.87%
# Hits@100: 95.35%
# Relation:
# For each left:
# Hits@1: 77.32%
# Hits@10: 82.61%
# Hits@50: 86.39%
# Hits@100: 89.98%
# For each right:
# Hits@1: 63.52%
# Hits@10: 70.51%
# Hits@50: 77.88%
# Hits@100: 82.04%
# 991/1000 epochs... 0.023090035
# 992/1000 epochs... 0.023090035
# 993/1000 epochs... 0.023090035
# 994/1000 epochs... 0.023090035
# 995/1000 epochs... 0.023090035
# 996/1000 epochs... 0.023090035
# 997/1000 epochs... 0.023090035
# 998/1000 epochs... 0.023090035
# 999/1000 epochs... 0.023090035
# Model saved in path: ./saved_model/ja_en/model_s3.ckpt
# 1000/1000 epochs... 0.023090035
# loss: [0.02845647, 0.028052848, 0.0276673, 0.02729826, 0.02694512, 0.026607191, 0.026283126, 0.025971904, 0.025672674, 0.025385465, 0.02511039, 0.024846504, 0.024593962, 0.024350898, 0.024118384, 0.023895346, 0.02368168, 0.023476541, 0.023281025, 0.023090035]
# Result:
# Entity:
# For each left:
# Hits@1: 76.90%
# Hits@10: 90.12%
# Hits@50: 94.44%
# Hits@100: 95.60%
# For each right:
# Hits@1: 73.30%
# Hits@10: 88.50%
# Hits@50: 93.87%
# Hits@100: 95.35%
# The output vector is saved in the file output_ja_en.npy

# %%
# save output to file
# !python main.py
# Out:
# WARNING:tensorflow:From main.py:18: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loading a file...data/ja_en/ent_ids_1
# loading a file...data/ja_en/ent_ids_2
# loading a file...data/ja_en/shuffled_ref_ent_ids
# loading a file...data/ja_en/ref_r_ids
# loading a file...data/ja_en/triples_1
# loading a file...data/ja_en/triples_2
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:263: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# adding the primal input layer...
# 39594 rows, 300 columns.
# getting a sparse tensor...
# tcmalloc: large alloc 12541485056 bytes == 0x1a64e000 @  0x7fd873d9d001 0x7fd871218765 0x7fd87127cbb0 0x7fd87127ea4f 0x7fd871315048 0x50a635 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7fd873998b97 0x5b250a
# calculate relation representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Init.py:17: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# first interaction...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:107: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:218: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# adding sparse attention layer...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:114: The name tf.sparse_softmax is deprecated. Please use tf.sparse.softmax instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:115: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# second interaction...
# adding sparse attention layer...
# getting loss...
# gcn layers...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:84: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# adding a diag layer...
# adding a diag layer...
# calculate joint entity representations
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:297: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# getting loss...
# getting loss...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:325: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:326: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# initializing...
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:330: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:331: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/.shortcut-targets-by-id/1UKNLJjkZsGmfTA2Kni94JqS325_jVhSt/Graduation research 3/RDGCN-Optimize/include/Model.py:332: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-06-07 10:40:52.711179: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-07 10:40:52.712860: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-06-07 10:40:52.712892: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d8702d1d7997): /proc/driver/nvidia/version does not exist
# 2020-06-07 10:40:52.719027: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-06-07 10:40:52.720528: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x28e2a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-07 10:40:52.720558: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# running...
# Model restore from path: None
# 1/1000 epochs... 0
# 2/1000 epochs... 0
# 3/1000 epochs... 0
# 4/1000 epochs... 0
# 5/1000 epochs... 0
# 6/1000 epochs... 0
# 7/1000 epochs... 0
# 8/1000 epochs... 0
# 9/1000 epochs... 0
# 10/1000 epochs... 0
# 11/1000 epochs... 0
# 12/1000 epochs... 0
# 13/1000 epochs... 0
# 14/1000 epochs... 0
# 15/1000 epochs... 0
# 16/1000 epochs... 0
# 17/1000 epochs... 0
# 18/1000 epochs... 0
# 19/1000 epochs... 0
# 20/1000 epochs... 0
# 21/1000 epochs... 0
# 22/1000 epochs... 0
# 23/1000 epochs... 0
# 24/1000 epochs... 0
# 25/1000 epochs... 0
# 26/1000 epochs... 0
# 27/1000 epochs... 0
# 28/1000 epochs... 0
# 29/1000 epochs... 0
# 30/1000 epochs... 0
# 31/1000 epochs... 0
# 32/1000 epochs... 0
# 33/1000 epochs... 0
# 34/1000 epochs... 0
# 35/1000 epochs... 0
# 36/1000 epochs... 0
# 37/1000 epochs... 0
# 38/1000 epochs... 0
# 39/1000 epochs... 0
# 40/1000 epochs... 0
# 41/1000 epochs... 0
# 42/1000 epochs... 0
# 43/1000 epochs... 0
# 44/1000 epochs... 0
# 45/1000 epochs... 0
# 46/1000 epochs... 0
# 47/1000 epochs... 0
# 48/1000 epochs... 0
# 49/1000 epochs... 0
# 50/1000 epochs... 0
# 51/1000 epochs... 0
# 52/1000 epochs... 0
# 53/1000 epochs... 0
# 54/1000 epochs... 0
# 55/1000 epochs... 0
# 56/1000 epochs... 0
# 57/1000 epochs... 0
# 58/1000 epochs... 0
# 59/1000 epochs... 0
# 60/1000 epochs... 0
# 61/1000 epochs... 0
# 62/1000 epochs... 0
# 63/1000 epochs... 0
# 64/1000 epochs... 0
# 65/1000 epochs... 0
# 66/1000 epochs... 0
# 67/1000 epochs... 0
# 68/1000 epochs... 0
# 69/1000 epochs... 0
# 70/1000 epochs... 0
# 71/1000 epochs... 0
# 72/1000 epochs... 0
# 73/1000 epochs... 0
# 74/1000 epochs... 0
# 75/1000 epochs... 0
# 76/1000 epochs... 0
# 77/1000 epochs... 0
# 78/1000 epochs... 0
# 79/1000 epochs... 0
# 80/1000 epochs... 0
# 81/1000 epochs... 0
# 82/1000 epochs... 0
# 83/1000 epochs... 0
# 84/1000 epochs... 0
# 85/1000 epochs... 0
# 86/1000 epochs... 0
# 87/1000 epochs... 0
# 88/1000 epochs... 0
# 89/1000 epochs... 0
# 90/1000 epochs... 0
# 91/1000 epochs... 0
# 92/1000 epochs... 0
# 93/1000 epochs... 0
# 94/1000 epochs... 0
# 95/1000 epochs... 0
# 96/1000 epochs... 0
# 97/1000 epochs... 0
# 98/1000 epochs... 0
# 99/1000 epochs... 0
# 100/1000 epochs... 0
# 101/1000 epochs... 0
# 102/1000 epochs... 0
# 103/1000 epochs... 0
# 104/1000 epochs... 0
# 105/1000 epochs... 0
# 106/1000 epochs... 0
# 107/1000 epochs... 0
# 108/1000 epochs... 0
# 109/1000 epochs... 0
# 110/1000 epochs... 0
# 111/1000 epochs... 0
# 112/1000 epochs... 0
# 113/1000 epochs... 0
# 114/1000 epochs... 0
# 115/1000 epochs... 0
# 116/1000 epochs... 0
# 117/1000 epochs... 0
# 118/1000 epochs... 0
# 119/1000 epochs... 0
# 120/1000 epochs... 0
# 121/1000 epochs... 0
# 122/1000 epochs... 0
# 123/1000 epochs... 0
# 124/1000 epochs... 0
# 125/1000 epochs... 0
# 126/1000 epochs... 0
# 127/1000 epochs... 0
# 128/1000 epochs... 0
# 129/1000 epochs... 0
# 130/1000 epochs... 0
# 131/1000 epochs... 0
# 132/1000 epochs... 0
# 133/1000 epochs... 0
# 134/1000 epochs... 0
# 135/1000 epochs... 0
# 136/1000 epochs... 0
# 137/1000 epochs... 0
# 138/1000 epochs... 0
# 139/1000 epochs... 0
# 140/1000 epochs... 0
# 141/1000 epochs... 0
# 142/1000 epochs... 0
# 143/1000 epochs... 0
# 144/1000 epochs... 0
# 145/1000 epochs... 0
# 146/1000 epochs... 0
# 147/1000 epochs... 0
# 148/1000 epochs... 0
# 149/1000 epochs... 0
# 150/1000 epochs... 0
# 151/1000 epochs... 0
# 152/1000 epochs... 0
# 153/1000 epochs... 0
# 154/1000 epochs... 0
# 155/1000 epochs... 0
# 156/1000 epochs... 0
# 157/1000 epochs... 0
# 158/1000 epochs... 0
# 159/1000 epochs... 0
# 160/1000 epochs... 0
# 161/1000 epochs... 0
# 162/1000 epochs... 0
# 163/1000 epochs... 0
# 164/1000 epochs... 0
# 165/1000 epochs... 0
# 166/1000 epochs... 0
# 167/1000 epochs... 0
# 168/1000 epochs... 0
# 169/1000 epochs... 0
# 170/1000 epochs... 0
# 171/1000 epochs... 0
# 172/1000 epochs... 0
# 173/1000 epochs... 0
# 174/1000 epochs... 0
# 175/1000 epochs... 0
# 176/1000 epochs... 0
# 177/1000 epochs... 0
# 178/1000 epochs... 0
# 179/1000 epochs... 0
# 180/1000 epochs... 0
# 181/1000 epochs... 0
# 182/1000 epochs... 0
# 183/1000 epochs... 0
# 184/1000 epochs... 0
# 185/1000 epochs... 0
# 186/1000 epochs... 0
# 187/1000 epochs... 0
# 188/1000 epochs... 0
# 189/1000 epochs... 0
# 190/1000 epochs... 0
# 191/1000 epochs... 0
# 192/1000 epochs... 0
# 193/1000 epochs... 0
# 194/1000 epochs... 0
# 195/1000 epochs... 0
# 196/1000 epochs... 0
# 197/1000 epochs... 0
# 198/1000 epochs... 0
# 199/1000 epochs... 0
# 200/1000 epochs... 0
# 201/1000 epochs... 0
# 202/1000 epochs... 0
# 203/1000 epochs... 0
# 204/1000 epochs... 0
# 205/1000 epochs... 0
# 206/1000 epochs... 0
# 207/1000 epochs... 0
# 208/1000 epochs... 0
# 209/1000 epochs... 0
# 210/1000 epochs... 0
# 211/1000 epochs... 0
# 212/1000 epochs... 0
# 213/1000 epochs... 0
# 214/1000 epochs... 0
# 215/1000 epochs... 0
# 216/1000 epochs... 0
# 217/1000 epochs... 0
# 218/1000 epochs... 0
# 219/1000 epochs... 0
# 220/1000 epochs... 0
# 221/1000 epochs... 0
# 222/1000 epochs... 0
# 223/1000 epochs... 0
# 224/1000 epochs... 0
# 225/1000 epochs... 0
# 226/1000 epochs... 0
# 227/1000 epochs... 0
# 228/1000 epochs... 0
# 229/1000 epochs... 0
# 230/1000 epochs... 0
# 231/1000 epochs... 0
# 232/1000 epochs... 0
# 233/1000 epochs... 0
# 234/1000 epochs... 0
# 235/1000 epochs... 0
# 236/1000 epochs... 0
# 237/1000 epochs... 0
# 238/1000 epochs... 0
# 239/1000 epochs... 0
# 240/1000 epochs... 0
# 241/1000 epochs... 0
# 242/1000 epochs... 0
# 243/1000 epochs... 0
# 244/1000 epochs... 0
# 245/1000 epochs... 0
# 246/1000 epochs... 0
# 247/1000 epochs... 0
# 248/1000 epochs... 0
# 249/1000 epochs... 0
# 250/1000 epochs... 0
# 251/1000 epochs... 0
# 252/1000 epochs... 0
# 253/1000 epochs... 0
# 254/1000 epochs... 0
# 255/1000 epochs... 0
# 256/1000 epochs... 0
# 257/1000 epochs... 0
# 258/1000 epochs... 0
# 259/1000 epochs... 0
# 260/1000 epochs... 0
# 261/1000 epochs... 0
# 262/1000 epochs... 0
# 263/1000 epochs... 0
# 264/1000 epochs... 0
# 265/1000 epochs... 0
# 266/1000 epochs... 0
# 267/1000 epochs... 0
# 268/1000 epochs... 0
# 269/1000 epochs... 0
# 270/1000 epochs... 0
# 271/1000 epochs... 0
# 272/1000 epochs... 0
# 273/1000 epochs... 0
# 274/1000 epochs... 0
# 275/1000 epochs... 0
# 276/1000 epochs... 0
# 277/1000 epochs... 0
# 278/1000 epochs... 0
# 279/1000 epochs... 0
# 280/1000 epochs... 0
# 281/1000 epochs... 0
# 282/1000 epochs... 0
# 283/1000 epochs... 0
# 284/1000 epochs... 0
# 285/1000 epochs... 0
# 286/1000 epochs... 0
# 287/1000 epochs... 0
# 288/1000 epochs... 0
# 289/1000 epochs... 0
# 290/1000 epochs... 0
# 291/1000 epochs... 0
# 292/1000 epochs... 0
# 293/1000 epochs... 0
# 294/1000 epochs... 0
# 295/1000 epochs... 0
# 296/1000 epochs... 0
# 297/1000 epochs... 0
# 298/1000 epochs... 0
# 299/1000 epochs... 0
# 300/1000 epochs... 0
# 301/1000 epochs... 0
# 302/1000 epochs... 0
# 303/1000 epochs... 0
# 304/1000 epochs... 0
# 305/1000 epochs... 0
# 306/1000 epochs... 0
# 307/1000 epochs... 0
# 308/1000 epochs... 0
# 309/1000 epochs... 0
# 310/1000 epochs... 0
# 311/1000 epochs... 0
# 312/1000 epochs... 0
# 313/1000 epochs... 0
# 314/1000 epochs... 0
# 315/1000 epochs... 0
# 316/1000 epochs... 0
# 317/1000 epochs... 0
# 318/1000 epochs... 0
# 319/1000 epochs... 0
# 320/1000 epochs... 0
# 321/1000 epochs... 0
# 322/1000 epochs... 0
# 323/1000 epochs... 0
# 324/1000 epochs... 0
# 325/1000 epochs... 0
# 326/1000 epochs... 0
# 327/1000 epochs... 0
# 328/1000 epochs... 0
# 329/1000 epochs... 0
# 330/1000 epochs... 0
# 331/1000 epochs... 0
# 332/1000 epochs... 0
# 333/1000 epochs... 0
# 334/1000 epochs... 0
# 335/1000 epochs... 0
# 336/1000 epochs... 0
# 337/1000 epochs... 0
# 338/1000 epochs... 0
# 339/1000 epochs... 0
# 340/1000 epochs... 0
# 341/1000 epochs... 0
# 342/1000 epochs... 0
# 343/1000 epochs... 0
# 344/1000 epochs... 0
# 345/1000 epochs... 0
# 346/1000 epochs... 0
# 347/1000 epochs... 0
# 348/1000 epochs... 0
# 349/1000 epochs... 0
# 350/1000 epochs... 0
# 351/1000 epochs... 0
# 352/1000 epochs... 0
# 353/1000 epochs... 0
# 354/1000 epochs... 0
# 355/1000 epochs... 0
# 356/1000 epochs... 0
# 357/1000 epochs... 0
# 358/1000 epochs... 0
# 359/1000 epochs... 0
# 360/1000 epochs... 0
# 361/1000 epochs... 0
# 362/1000 epochs... 0
# 363/1000 epochs... 0
# 364/1000 epochs... 0
# 365/1000 epochs... 0
# 366/1000 epochs... 0
# 367/1000 epochs... 0
# 368/1000 epochs... 0
# 369/1000 epochs... 0
# 370/1000 epochs... 0
# 371/1000 epochs... 0
# 372/1000 epochs... 0
# 373/1000 epochs... 0
# 374/1000 epochs... 0
# 375/1000 epochs... 0
# 376/1000 epochs... 0
# 377/1000 epochs... 0
# 378/1000 epochs... 0
# 379/1000 epochs... 0
# 380/1000 epochs... 0
# 381/1000 epochs... 0
# 382/1000 epochs... 0
# 383/1000 epochs... 0
# 384/1000 epochs... 0
# 385/1000 epochs... 0
# 386/1000 epochs... 0
# 387/1000 epochs... 0
# 388/1000 epochs... 0
# 389/1000 epochs... 0
# 390/1000 epochs... 0
# 391/1000 epochs... 0
# 392/1000 epochs... 0
# 393/1000 epochs... 0
# 394/1000 epochs... 0
# 395/1000 epochs... 0
# 396/1000 epochs... 0
# 397/1000 epochs... 0
# 398/1000 epochs... 0
# 399/1000 epochs... 0
# 400/1000 epochs... 0
# 401/1000 epochs... 0
# 402/1000 epochs... 0
# 403/1000 epochs... 0
# 404/1000 epochs... 0
# 405/1000 epochs... 0
# 406/1000 epochs... 0
# 407/1000 epochs... 0
# 408/1000 epochs... 0
# 409/1000 epochs... 0
# 410/1000 epochs... 0
# 411/1000 epochs... 0
# 412/1000 epochs... 0
# 413/1000 epochs... 0
# 414/1000 epochs... 0
# 415/1000 epochs... 0
# 416/1000 epochs... 0
# 417/1000 epochs... 0
# 418/1000 epochs... 0
# 419/1000 epochs... 0
# 420/1000 epochs... 0
# 421/1000 epochs... 0
# 422/1000 epochs... 0
# 423/1000 epochs... 0
# 424/1000 epochs... 0
# 425/1000 epochs... 0
# 426/1000 epochs... 0
# 427/1000 epochs... 0
# 428/1000 epochs... 0
# 429/1000 epochs... 0
# 430/1000 epochs... 0
# 431/1000 epochs... 0
# 432/1000 epochs... 0
# 433/1000 epochs... 0
# 434/1000 epochs... 0
# 435/1000 epochs... 0
# 436/1000 epochs... 0
# 437/1000 epochs... 0
# 438/1000 epochs... 0
# 439/1000 epochs... 0
# 440/1000 epochs... 0
# 441/1000 epochs... 0
# 442/1000 epochs... 0
# 443/1000 epochs... 0
# 444/1000 epochs... 0
# 445/1000 epochs... 0
# 446/1000 epochs... 0
# 447/1000 epochs... 0
# 448/1000 epochs... 0
# 449/1000 epochs... 0
# 450/1000 epochs... 0
# 451/1000 epochs... 0
# 452/1000 epochs... 0
# 453/1000 epochs... 0
# 454/1000 epochs... 0
# 455/1000 epochs... 0
# 456/1000 epochs... 0
# 457/1000 epochs... 0
# 458/1000 epochs... 0
# 459/1000 epochs... 0
# 460/1000 epochs... 0
# 461/1000 epochs... 0
# 462/1000 epochs... 0
# 463/1000 epochs... 0
# 464/1000 epochs... 0
# 465/1000 epochs... 0
# 466/1000 epochs... 0
# 467/1000 epochs... 0
# 468/1000 epochs... 0
# 469/1000 epochs... 0
# 470/1000 epochs... 0
# 471/1000 epochs... 0
# 472/1000 epochs... 0
# 473/1000 epochs... 0
# 474/1000 epochs... 0
# 475/1000 epochs... 0
# 476/1000 epochs... 0
# 477/1000 epochs... 0
# 478/1000 epochs... 0
# 479/1000 epochs... 0
# 480/1000 epochs... 0
# 481/1000 epochs... 0
# 482/1000 epochs... 0
# 483/1000 epochs... 0
# 484/1000 epochs... 0
# 485/1000 epochs... 0
# 486/1000 epochs... 0
# 487/1000 epochs... 0
# 488/1000 epochs... 0
# 489/1000 epochs... 0
# 490/1000 epochs... 0
# 491/1000 epochs... 0
# 492/1000 epochs... 0
# 493/1000 epochs... 0
# 494/1000 epochs... 0
# 495/1000 epochs... 0
# 496/1000 epochs... 0
# 497/1000 epochs... 0
# 498/1000 epochs... 0
# 499/1000 epochs... 0
# 500/1000 epochs... 0
# 501/1000 epochs... 0
# 502/1000 epochs... 0
# 503/1000 epochs... 0
# 504/1000 epochs... 0
# 505/1000 epochs... 0
# 506/1000 epochs... 0
# 507/1000 epochs... 0
# 508/1000 epochs... 0
# 509/1000 epochs... 0
# 510/1000 epochs... 0
# 511/1000 epochs... 0
# 512/1000 epochs... 0
# 513/1000 epochs... 0
# 514/1000 epochs... 0
# 515/1000 epochs... 0
# 516/1000 epochs... 0
# 517/1000 epochs... 0
# 518/1000 epochs... 0
# 519/1000 epochs... 0
# 520/1000 epochs... 0
# 521/1000 epochs... 0
# 522/1000 epochs... 0
# 523/1000 epochs... 0
# 524/1000 epochs... 0
# 525/1000 epochs... 0
# 526/1000 epochs... 0
# 527/1000 epochs... 0
# 528/1000 epochs... 0
# 529/1000 epochs... 0
# 530/1000 epochs... 0
# 531/1000 epochs... 0
# 532/1000 epochs... 0
# 533/1000 epochs... 0
# 534/1000 epochs... 0
# 535/1000 epochs... 0
# 536/1000 epochs... 0
# 537/1000 epochs... 0
# 538/1000 epochs... 0
# 539/1000 epochs... 0
# 540/1000 epochs... 0
# 541/1000 epochs... 0
# 542/1000 epochs... 0
# 543/1000 epochs... 0
# 544/1000 epochs... 0
# 545/1000 epochs... 0
# 546/1000 epochs... 0
# 547/1000 epochs... 0
# 548/1000 epochs... 0
# 549/1000 epochs... 0
# 550/1000 epochs... 0
# 551/1000 epochs... 0
# 552/1000 epochs... 0
# 553/1000 epochs... 0
# 554/1000 epochs... 0
# 555/1000 epochs... 0
# 556/1000 epochs... 0
# 557/1000 epochs... 0
# 558/1000 epochs... 0
# 559/1000 epochs... 0
# 560/1000 epochs... 0
# 561/1000 epochs... 0
# 562/1000 epochs... 0
# 563/1000 epochs... 0
# 564/1000 epochs... 0
# 565/1000 epochs... 0
# 566/1000 epochs... 0
# 567/1000 epochs... 0
# 568/1000 epochs... 0
# 569/1000 epochs... 0
# 570/1000 epochs... 0
# 571/1000 epochs... 0
# 572/1000 epochs... 0
# 573/1000 epochs... 0
# 574/1000 epochs... 0
# 575/1000 epochs... 0
# 576/1000 epochs... 0
# 577/1000 epochs... 0
# 578/1000 epochs... 0
# 579/1000 epochs... 0
# 580/1000 epochs... 0
# 581/1000 epochs... 0
# 582/1000 epochs... 0
# 583/1000 epochs... 0
# 584/1000 epochs... 0
# 585/1000 epochs... 0
# 586/1000 epochs... 0
# 587/1000 epochs... 0
# 588/1000 epochs... 0
# 589/1000 epochs... 0
# 590/1000 epochs... 0
# 591/1000 epochs... 0
# 592/1000 epochs... 0
# 593/1000 epochs... 0
# 594/1000 epochs... 0
# 595/1000 epochs... 0
# 596/1000 epochs... 0
# 597/1000 epochs... 0
# 598/1000 epochs... 0
# 599/1000 epochs... 0
# 600/1000 epochs... 0
# 601/1000 epochs... 0
# 602/1000 epochs... 0
# 603/1000 epochs... 0
# 604/1000 epochs... 0
# 605/1000 epochs... 0
# 606/1000 epochs... 0
# 607/1000 epochs... 0
# 608/1000 epochs... 0
# 609/1000 epochs... 0
# 610/1000 epochs... 0
# 611/1000 epochs... 0
# 612/1000 epochs... 0
# 613/1000 epochs... 0
# 614/1000 epochs... 0
# 615/1000 epochs... 0
# 616/1000 epochs... 0
# 617/1000 epochs... 0
# 618/1000 epochs... 0
# 619/1000 epochs... 0
# 620/1000 epochs... 0
# 621/1000 epochs... 0
# 622/1000 epochs... 0
# 623/1000 epochs... 0
# 624/1000 epochs... 0
# 625/1000 epochs... 0
# 626/1000 epochs... 0
# 627/1000 epochs... 0
# 628/1000 epochs... 0
# 629/1000 epochs... 0
# 630/1000 epochs... 0
# 631/1000 epochs... 0
# 632/1000 epochs... 0
# 633/1000 epochs... 0
# 634/1000 epochs... 0
# 635/1000 epochs... 0
# 636/1000 epochs... 0
# 637/1000 epochs... 0
# 638/1000 epochs... 0
# 639/1000 epochs... 0
# 640/1000 epochs... 0
# 641/1000 epochs... 0
# 642/1000 epochs... 0
# 643/1000 epochs... 0
# 644/1000 epochs... 0
# 645/1000 epochs... 0
# 646/1000 epochs... 0
# 647/1000 epochs... 0
# 648/1000 epochs... 0
# 649/1000 epochs... 0
# 650/1000 epochs... 0
# 651/1000 epochs... 0
# 652/1000 epochs... 0
# 653/1000 epochs... 0
# 654/1000 epochs... 0
# 655/1000 epochs... 0
# 656/1000 epochs... 0
# 657/1000 epochs... 0
# 658/1000 epochs... 0
# 659/1000 epochs... 0
# 660/1000 epochs... 0
# 661/1000 epochs... 0
# 662/1000 epochs... 0
# 663/1000 epochs... 0
# 664/1000 epochs... 0
# 665/1000 epochs... 0
# 666/1000 epochs... 0
# 667/1000 epochs... 0
# 668/1000 epochs... 0
# 669/1000 epochs... 0
# 670/1000 epochs... 0
# 671/1000 epochs... 0
# 672/1000 epochs... 0
# 673/1000 epochs... 0
# 674/1000 epochs... 0
# 675/1000 epochs... 0
# 676/1000 epochs... 0
# 677/1000 epochs... 0
# 678/1000 epochs... 0
# 679/1000 epochs... 0
# 680/1000 epochs... 0
# 681/1000 epochs... 0
# 682/1000 epochs... 0
# 683/1000 epochs... 0
# 684/1000 epochs... 0
# 685/1000 epochs... 0
# 686/1000 epochs... 0
# 687/1000 epochs... 0
# 688/1000 epochs... 0
# 689/1000 epochs... 0
# 690/1000 epochs... 0
# 691/1000 epochs... 0
# 692/1000 epochs... 0
# 693/1000 epochs... 0
# 694/1000 epochs... 0
# 695/1000 epochs... 0
# 696/1000 epochs... 0
# 697/1000 epochs... 0
# 698/1000 epochs... 0
# 699/1000 epochs... 0
# 700/1000 epochs... 0
# 701/1000 epochs... 0
# 702/1000 epochs... 0
# 703/1000 epochs... 0
# 704/1000 epochs... 0
# 705/1000 epochs... 0
# 706/1000 epochs... 0
# 707/1000 epochs... 0
# 708/1000 epochs... 0
# 709/1000 epochs... 0
# 710/1000 epochs... 0
# 711/1000 epochs... 0
# 712/1000 epochs... 0
# 713/1000 epochs... 0
# 714/1000 epochs... 0
# 715/1000 epochs... 0
# 716/1000 epochs... 0
# 717/1000 epochs... 0
# 718/1000 epochs... 0
# 719/1000 epochs... 0
# 720/1000 epochs... 0
# 721/1000 epochs... 0
# 722/1000 epochs... 0
# 723/1000 epochs... 0
# 724/1000 epochs... 0
# 725/1000 epochs... 0
# 726/1000 epochs... 0
# 727/1000 epochs... 0
# 728/1000 epochs... 0
# 729/1000 epochs... 0
# 730/1000 epochs... 0
# 731/1000 epochs... 0
# 732/1000 epochs... 0
# 733/1000 epochs... 0
# 734/1000 epochs... 0
# 735/1000 epochs... 0
# 736/1000 epochs... 0
# 737/1000 epochs... 0
# 738/1000 epochs... 0
# 739/1000 epochs... 0
# 740/1000 epochs... 0
# 741/1000 epochs... 0
# 742/1000 epochs... 0
# 743/1000 epochs... 0
# 744/1000 epochs... 0
# 745/1000 epochs... 0
# 746/1000 epochs... 0
# 747/1000 epochs... 0
# 748/1000 epochs... 0
# 749/1000 epochs... 0
# 750/1000 epochs... 0
# 751/1000 epochs... 0
# 752/1000 epochs... 0
# 753/1000 epochs... 0
# 754/1000 epochs... 0
# 755/1000 epochs... 0
# 756/1000 epochs... 0
# 757/1000 epochs... 0
# 758/1000 epochs... 0
# 759/1000 epochs... 0
# 760/1000 epochs... 0
# 761/1000 epochs... 0
# 762/1000 epochs... 0
# 763/1000 epochs... 0
# 764/1000 epochs... 0
# 765/1000 epochs... 0
# 766/1000 epochs... 0
# 767/1000 epochs... 0
# 768/1000 epochs... 0
# 769/1000 epochs... 0
# 770/1000 epochs... 0
# 771/1000 epochs... 0
# 772/1000 epochs... 0
# 773/1000 epochs... 0
# 774/1000 epochs... 0
# 775/1000 epochs... 0
# 776/1000 epochs... 0
# 777/1000 epochs... 0
# 778/1000 epochs... 0
# 779/1000 epochs... 0
# 780/1000 epochs... 0
# 781/1000 epochs... 0
# 782/1000 epochs... 0
# 783/1000 epochs... 0
# 784/1000 epochs... 0
# 785/1000 epochs... 0
# 786/1000 epochs... 0
# 787/1000 epochs... 0
# 788/1000 epochs... 0
# 789/1000 epochs... 0
# 790/1000 epochs... 0
# 791/1000 epochs... 0
# 792/1000 epochs... 0
# 793/1000 epochs... 0
# 794/1000 epochs... 0
# 795/1000 epochs... 0
# 796/1000 epochs... 0
# 797/1000 epochs... 0
# 798/1000 epochs... 0
# 799/1000 epochs... 0
# 800/1000 epochs... 0
# 801/1000 epochs... 0
# 802/1000 epochs... 0
# 803/1000 epochs... 0
# 804/1000 epochs... 0
# 805/1000 epochs... 0
# 806/1000 epochs... 0
# 807/1000 epochs... 0
# 808/1000 epochs... 0
# 809/1000 epochs... 0
# 810/1000 epochs... 0
# 811/1000 epochs... 0
# 812/1000 epochs... 0
# 813/1000 epochs... 0
# 814/1000 epochs... 0
# 815/1000 epochs... 0
# 816/1000 epochs... 0
# 817/1000 epochs... 0
# 818/1000 epochs... 0
# 819/1000 epochs... 0
# 820/1000 epochs... 0
# 821/1000 epochs... 0
# 822/1000 epochs... 0
# 823/1000 epochs... 0
# 824/1000 epochs... 0
# 825/1000 epochs... 0
# 826/1000 epochs... 0
# 827/1000 epochs... 0
# 828/1000 epochs... 0
# 829/1000 epochs... 0
# 830/1000 epochs... 0
# 831/1000 epochs... 0
# 832/1000 epochs... 0
# 833/1000 epochs... 0
# 834/1000 epochs... 0
# 835/1000 epochs... 0
# 836/1000 epochs... 0
# 837/1000 epochs... 0
# 838/1000 epochs... 0
# 839/1000 epochs... 0
# 840/1000 epochs... 0
# 841/1000 epochs... 0
# 842/1000 epochs... 0
# 843/1000 epochs... 0
# 844/1000 epochs... 0
# 845/1000 epochs... 0
# 846/1000 epochs... 0
# 847/1000 epochs... 0
# 848/1000 epochs... 0
# 849/1000 epochs... 0
# 850/1000 epochs... 0
# 851/1000 epochs... 0
# 852/1000 epochs... 0
# 853/1000 epochs... 0
# 854/1000 epochs... 0
# 855/1000 epochs... 0
# 856/1000 epochs... 0
# 857/1000 epochs... 0
# 858/1000 epochs... 0
# 859/1000 epochs... 0
# 860/1000 epochs... 0
# 861/1000 epochs... 0
# 862/1000 epochs... 0
# 863/1000 epochs... 0
# 864/1000 epochs... 0
# 865/1000 epochs... 0
# 866/1000 epochs... 0
# 867/1000 epochs... 0
# 868/1000 epochs... 0
# 869/1000 epochs... 0
# 870/1000 epochs... 0
# 871/1000 epochs... 0
# 872/1000 epochs... 0
# 873/1000 epochs... 0
# 874/1000 epochs... 0
# 875/1000 epochs... 0
# 876/1000 epochs... 0
# 877/1000 epochs... 0
# 878/1000 epochs... 0
# 879/1000 epochs... 0
# 880/1000 epochs... 0
# 881/1000 epochs... 0
# 882/1000 epochs... 0
# 883/1000 epochs... 0
# 884/1000 epochs... 0
# 885/1000 epochs... 0
# 886/1000 epochs... 0
# 887/1000 epochs... 0
# 888/1000 epochs... 0
# 889/1000 epochs... 0
# 890/1000 epochs... 0
# 891/1000 epochs... 0
# 892/1000 epochs... 0
# 893/1000 epochs... 0
# 894/1000 epochs... 0
# 895/1000 epochs... 0
# 896/1000 epochs... 0
# 897/1000 epochs... 0
# 898/1000 epochs... 0
# 899/1000 epochs... 0
# 900/1000 epochs... 0
# 901/1000 epochs... 0
# 902/1000 epochs... 0
# 903/1000 epochs... 0
# 904/1000 epochs... 0
# 905/1000 epochs... 0
# 906/1000 epochs... 0
# 907/1000 epochs... 0
# 908/1000 epochs... 0
# 909/1000 epochs... 0
# 910/1000 epochs... 0
# 911/1000 epochs... 0
# 912/1000 epochs... 0
# 913/1000 epochs... 0
# 914/1000 epochs... 0
# 915/1000 epochs... 0
# 916/1000 epochs... 0
# 917/1000 epochs... 0
# 918/1000 epochs... 0
# 919/1000 epochs... 0
# 920/1000 epochs... 0
# 921/1000 epochs... 0
# 922/1000 epochs... 0
# 923/1000 epochs... 0
# 924/1000 epochs... 0
# 925/1000 epochs... 0
# 926/1000 epochs... 0
# 927/1000 epochs... 0
# 928/1000 epochs... 0
# 929/1000 epochs... 0
# 930/1000 epochs... 0
# 931/1000 epochs... 0
# 932/1000 epochs... 0
# 933/1000 epochs... 0
# 934/1000 epochs... 0
# 935/1000 epochs... 0
# 936/1000 epochs... 0
# 937/1000 epochs... 0
# 938/1000 epochs... 0
# 939/1000 epochs... 0
# 940/1000 epochs... 0
# 941/1000 epochs... 0
# 942/1000 epochs... 0
# 943/1000 epochs... 0
# 944/1000 epochs... 0
# 945/1000 epochs... 0
# 946/1000 epochs... 0
# 947/1000 epochs... 0
# 948/1000 epochs... 0
# 949/1000 epochs... 0
# 950/1000 epochs... 0
# 951/1000 epochs... 0
# 952/1000 epochs... 0
# 953/1000 epochs... 0
# 954/1000 epochs... 0
# 955/1000 epochs... 0
# 956/1000 epochs... 0
# 957/1000 epochs... 0
# 958/1000 epochs... 0
# 959/1000 epochs... 0
# 960/1000 epochs... 0
# 961/1000 epochs... 0
# 962/1000 epochs... 0
# 963/1000 epochs... 0
# 964/1000 epochs... 0
# 965/1000 epochs... 0
# 966/1000 epochs... 0
# 967/1000 epochs... 0
# 968/1000 epochs... 0
# 969/1000 epochs... 0
# 970/1000 epochs... 0
# 971/1000 epochs... 0
# 972/1000 epochs... 0
# 973/1000 epochs... 0
# 974/1000 epochs... 0
# 975/1000 epochs... 0
# 976/1000 epochs... 0
# 977/1000 epochs... 0
# 978/1000 epochs... 0
# 979/1000 epochs... 0
# 980/1000 epochs... 0
# 981/1000 epochs... 0
# 982/1000 epochs... 0
# 983/1000 epochs... 0
# 984/1000 epochs... 0
# 985/1000 epochs... 0
# 986/1000 epochs... 0
# 987/1000 epochs... 0
# 988/1000 epochs... 0
# 989/1000 epochs... 0
# 990/1000 epochs... 0
# 991/1000 epochs... 0
# 992/1000 epochs... 0
# 993/1000 epochs... 0
# 994/1000 epochs... 0
# 995/1000 epochs... 0
# 996/1000 epochs... 0
# 997/1000 epochs... 0
# 998/1000 epochs... 0
# 999/1000 epochs... 0
# 1000/1000 epochs... 0
# loss: []
# Result:
# Entity:
# For each left:
# Hits@1: 76.88%
# Hits@10: 90.11%
# Hits@50: 94.39%
# Hits@100: 95.60%
# For each right:
# Hits@1: 73.28%
# Hits@10: 88.49%
# Hits@50: 93.84%
# Hits@100: 95.34%
# The output vector is saved in the file output_ja_en.npy

# %%
import numpy as np
outvec = np.load('output_ja_en.npy')
print(outvec)
print(outvec.shape)
# Out:
# [[ 4.96691763e-02  2.38986444e-02  1.12246992e-02 ...  1.41462404e-03
#    1.33184949e-03 -2.05687247e-04]
#  [ 2.55510537e-03 -1.64406672e-02  1.45050008e-02 ...  2.50104256e-02
#    5.01377769e-02 -7.23205646e-03]
#  [-1.77626796e-02 -1.25866663e-02  1.11669330e-02 ... -6.27379119e-02
#   -3.01964432e-02 -5.12220487e-02]
#  ...
#  [ 5.94583619e-03 -1.89927686e-02 -7.57942500e-04 ... -2.49250792e-04
#   -1.65970996e-05 -7.55516812e-05]
#  [-1.86115671e-02  5.41111338e-04 -6.91146590e-03 ...  2.16302369e-03
#   -3.40443105e-03 -4.40319534e-03]
#  [ 5.71258143e-02 -3.40274908e-03 -1.32879168e-02 ...  1.04343835e-02
#    2.76408996e-03 -9.26702656e-03]]
# (39594, 400)

# %%
from include.Test import get_hits
from include.Load import *
from include.Config import Config
ILL = loadfile(Config.shuffled_ill, 2)
illL = len(ILL)
train = np.array(ILL[:illL // 10 * Config.seed])
test = ILL[illL // 10 * Config.seed:]
get_hits(outvec, test)
# Out:
# loading a file...data/ja_en/shuffled_ref_ent_ids
# Entity:
# For each left:
# Hits@1: 76.88%
# Hits@10: 90.11%
# Hits@50: 94.39%
# Hits@100: 95.60%
# For each right:
# Hits@1: 73.28%
# Hits@10: 88.49%
# Hits@50: 93.84%
# Hits@100: 95.34%
